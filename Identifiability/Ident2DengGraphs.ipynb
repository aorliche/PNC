# %%
import matplotlib.pyplot as plt

# Identifiability in Longitudinal Data
# Age and sex

subs = ['Null Model', '1350', '200', '100', '50']
ages_rmse = [7.62, 5.33, 5.18, 5.02, 4.97]
sex_acc = [.528, .89, .871, .86, .887]

fig, ax = plt.subplots(1,2,figsize=(12,4))
fig.subplots_adjust(top=0.8)

# ax[0].plot([0,3], [7.62, 7.62], linestyle='--', color='black', label='Null Model')
ax[0].plot([-0.3,4.3], [7.31, 7.31], linestyle='--', color='black', label='200 Non-Repeated Subs')
ax[0].plot([-0.3,4.3], [6.04, 6.04], linestyle='--', color='orange', label='3,000 Non-Repeated Subs')
ax[0].plot([-0.3,4.3], [5.63, 5.63], linestyle='--', color='red', label='10,000 Non-Repeated Subs')
ax[0].bar(subs, ages_rmse)
ax[0].set_title('Age Prediction with Same Subject, Different Scan')
ax[0].set_xlabel('# Training Subjects')
ax[0].set_ylabel('Age RMSE (years)')
ax[0].set_ylim([4.8,8])
ax[0].legend()

ax[1].plot([-0.3,4.3], [.75, .75], linestyle='--', color='black', label='200 Non-Repeated Subs')
ax[1].plot([-0.3,4.3], [.826, .826], linestyle='--', color='orange', label='3,000 Non-Repeated Subs')
ax[1].plot([-0.3,4.3], [.863, .863], linestyle='--', color='red', label='10,000 Non-Repeated Subs')
ax[1].bar(subs, sex_acc)
ax[1].set_title('Sex Prediction with Same Subject, Different Scan')
ax[1].set_xlabel('# Training Subjects')
ax[1].set_ylabel('Accuracy')
ax[1].set_ylim([.5,.92])
ax[1].legend()

fig.suptitle('UKB Longitudinal Cohort Power264\nLinear Models')
fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/Identifiability/ukb_long_cheating.pdf')
# Out:
# /tmp/ipykernel_371600/2796930398.py:35: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Identifiability in Fibromyalgia Dataset

import numpy as np

fig, ax = plt.subplots(1,1,figsize=(6,4))
fig.subplots_adjust(top=0.8)

subs = ['Double-Dip\nRest to Epr', 'Double-Dip\nEpr to Rest', 'Mixed', 'Rest to Epr', 'Epr to Rest']
accs = [0.856, 0.858, 0.607, 0.573, 0.573]
errs = np.array([0.033, 0.038, 0.173, 0.153, 0.152])/np.sqrt(20)

ax.plot([-0.3,4.3], [0.5,0.5], color='black', linestyle='--', label='Null Model')
ax.bar(subs, accs, yerr=errs, capsize=5)
ax.set_title('Fibromyalgia Status Prediction 50 Train 15 Test 20 Reps')
ax.set_xlabel('(Training Scans) to (Test Scans)')
ax.set_ylabel('Accuracy')
ax.set_ylim([0.45,0.9])
ax.legend()

fig.suptitle('Fibromyalgia Cohort Power264\nLogistic Regression')
fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/Identifiability/fibro_cheating.pdf')
# Out:
# /tmp/ipykernel_371600/1624987687.py:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Identifiability in PNC WRAT

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1,1,figsize=(10,4))
fig.subplots_adjust(top=0.8)

subs = ['AA Emoid',  'Double-Dip\nAA Nback, Emoid', 'Double-Dip\nAA Emoid, Nback',
       'EA Emoid', 'Double-Dip\nEA Nback, Emoid', 'Double-Dip\nEA Emoid, Nback']
rmse = [14.45, 11.65, 11.31, 14.6, 11, 10.84]
errs = np.array([0.92, 0.25, 0.25, 0.75, 0.19, 0.29])/np.sqrt(10)

ax.plot([-0.3,2.3],[14.5,14.5],label='Null Model',color='black',linestyle='--')
ax.plot([2.7,5.3],[14.65,14.65],color='black',linestyle='--')
ax.bar(subs, rmse, yerr=errs, capsize=5)
ax.set_title('WRAT Score Prediction 500 Train 100+ Test 20 Reps')
ax.set_xlabel('(Training Scans), (Test Scans)')
ax.set_ylabel('WRAT Score RMSE')
ax.set_ylim([9,15])
ax.legend()

fig.suptitle('PNC Power264\nRidge with Best $\\alpha=10...10000$')
fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/Identifiability/pnc_wrat_cheating.pdf')
# Out:
# /tmp/ipykernel_382466/687753250.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# BSNIP Dynamic FC

fig, ax = plt.subplots(1,1,figsize=(8,4))
fig.subplots_adjust(top=0.8)

subs = ['Null Model', 'Best FC\n199 SZ 199 NC', 'Double-Dip DFC\n25 SZ 25 NC', 'DFC 25 SZ 25 NC']
acc = [0.5, 0.785, 0.895, 0.644]
errs = np.array([0, 0.048, 0.047, 0.0801])/np.sqrt(10)

ax.bar(subs, acc, yerr=errs, capsize=5)
ax.set_title('SZ Status Prediction')
ax.set_xlabel('Training/Test Sets')
ax.set_ylabel('Accuracy')
ax.set_ylim([0.45,0.92])

fig.suptitle('BSNIP Cohort Power264\nLogistic Regression')
fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/Identifiability/bsnip_dfc_cheating.pdf')
# Out:
# /tmp/ipykernel_382466/1238949821.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

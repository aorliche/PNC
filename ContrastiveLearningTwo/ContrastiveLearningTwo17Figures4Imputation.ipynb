# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1,1,figsize=(6,4))

miss = [100, 500, 2000, 5000, 10000, 15000, 20000, 25000, 30000, 35000]
miss = np.array(miss)/35621*100
pca = [0.633017316,0.6255229437,0.6252735931,0.6259327273,0.6247150216,0.6229162771,0.6203011905,0.6151855758,0.6102435209,0.603695201]
vae = [0.9014220779,0.8988536797,0.8976064935,0.8957578355,0.8924732468,0.879835469,0.8559531602,0.8104830476,0.7178222367,0.5357941744]
vae_nosexrace = [0.8605930736,0.8596978355,0.8572244589,0.8518489177,0.8398488312,
                 0.8240369408,0.7955908658,0.7397683117,0.6417443146,0.4726809153]
fa = []

ax.plot(miss, 100*np.array(pca), label='PCA', marker='o')
ax.plot(miss, 100*np.array(vae), label='VAE', marker='o')
ax.plot(miss, 100*np.array(vae_nosexrace), label='VAE, No Sex/Race', marker='o')

ax.set_title('Imputation of Missing SNPs')
ax.set_xlabel('% SNPs Missing')
ax.set_ylabel('% Missing SNPs Imputed Correctly')\

fig.savefig('/home/anton/Documents/Tulane/Research/Work/CL-VAE/missing-snp-imputation.pdf')
fig.show()

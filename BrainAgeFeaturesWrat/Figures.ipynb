# %%
import matplotlib.pyplot as plt
import numpy as np

# Resting paradigm
# title = 'All Subjects'
# tp = 0.0691
# N = 804
# vWrat = np.array((-0.0869, 0.0175, 0.000485, 0.0468, 0.0381, 0.0184))
# baDiffvWrat = np.array((0, 0.126, 0.117, 0.134, 0.135, 0.114))
# theo = np.array((0, 0.08, 0.0707, 0.0982, 0.0913, 0.0822))
# diff = np.array((0, 0.1044, 0.087385, 0.1337, 0.125, 0.1053))

# Resting male paradigm
# title = 'Male Subjects'
# tp = 0.102
# N = 369
# vWrat = np.array((-0.0518, 0.0349, 0.0261, 0.0661, 0.0515, 0.0678))
# baDiffvWrat = np.array((0,0.108, 0.103, 0.114, 0.119, 0.123))
# theo = np.array((0,0.0623,0.057,0.0805,0.0729,0.0814))
# diff = np.array((0,0.0867,0.0779,0.1179,0.1033,0.1196))

# Resting female paradigm
title = 'Female Subjects'
tp = 0.094
N = 435
vWrat = np.array((-0.111,0.009,-0.0189,0.0392,0.0311,-0.00751))
baDiffvWrat = np.array((0,0.141,0.128,0.151,0.146,0.115))
# theo = np.array((0,0.0956,0.0829,0.115,0.106,0.089))
# diff = np.array((0,0.12,0.0921,0.1502,0.1421,0.10349))

# Resting paradigm 8-12
# title = '8-12 Year Olds'
# tp = 0.149
# N = 174
# vWrat = np.array((-0.171,0.0175,-0.0236,-0.0367,0.00367,-0.0764))
# baDiffvWrat = np.array((0,0.0923,0.0725,0.0547,0.0903,0.00515))

# Resting paradigm 12-18
# title = '12-18 Year Olds'
# tp = 0.093
# N = 445
# vWrat = np.array((-0.0406,0.086,0.0632,0.108,0.101,0.0439))
# baDiffvWrat = np.array((0,0.119,0.0997,0.128,0.128,0.0716))

# Resting paradigm 18-22
# title = '18-22 Year Olds'
# tp = 0.144
# N = 185
# vWrat = np.array((0.129,0.076,0.087,0.139,0.1,0.231))
# baDiffvWrat = np.array((0,0.0153,0.0134,0.0669,0.0484,0.158))

# Nback paradigm
# title = 'All Subjects'
# tp = 0.0674
# N = 846
# vWrat = np.array((-0.076,-0.00966,-0.00322,0.0393,0.00443,-0.0481))
# baDiffvWrat = np.array((0,0.101,0.0803,0.136,0.111,0.05))
# theo = np.array((0,0.0534,0.0406,0.0846,0.0617,0.0326))
# diff = np.array((0,0.06634,0.07278,0.1153,0.08043,0.0279))

# Nback male paradigm
# title = 'Male Subjects'
# tp = 0.0988
# N = 394
# vWrat = np.array((-0.0286,0.00159,-0.027,0.0235,0.0241,-0.0629))
# baDiffvWrat = np.array((0,0.0423,0.0104,0.0622,0.0739,-0.0264))

# Nback female paradigm
# title = 'Female Subjects'
# tp = 0.0922
# N = 452
# vWrat = np.array((-0.111,-0.00566,-0.0228,0.0694,-0.000195,-0.013))
# baDiffvWrat = np.array((0,0.15,0.141,0.202,0.147,0.124))

# Nback paradigm 8-12
# title = '8-12 Year Olds'
# tp = 0.142
# N = 191
# vWrat = np.array((-0.142,-0.0998,-0.143,-0.0792,-0.0937,-0.102))
# baDiffvWrat = np.array((0,-0.0243,-0.07,0.00907,-0.0177,-0.0244))

# Nback paradigm 12-18
# title = '12-18 Year Olds'
# tp = 0.0908
# N = 467
# vWrat = np.array((-0.0314,0.0758,0.0503,0.113,0.0912,0.0231))
# baDiffvWrat = np.array((0,0.114,0.0889,0.142,0.126,0.0476))

# Nback paradigm 18-22
# title = '18-22 Year Olds'
# tp = 0.143
# N = 188
# vWrat = np.array((0.13,0.0565,0.051,0.14,0.0645,-0.0928))
# baDiffvWrat = np.array((0,-0.0228,-0.0368,0.0629,-0.00924,-0.145))

# Emoid paradigm
# title = 'All Subjects'
# tp = 0.0788
# N = 620
# vWrat = np.array((-0.0988,-0.0326,-0.0425,0.00378,-0.0158,-0.0115))
# baDiffvWrat = np.array((0,0.106,0.104,0.134,0.116,0.116))
# theo = np.array((0,0.0579,0.0537,0.0832,0.0665,0.0751))
# diff = np.array((0,0.0662,0.0563,0.10258,0.083,0.0873))

# Emoid male paradigm
# title = 'Male Subjects'
# tp = 0.116
# N = 286
# vWrat = np.array((-0.0742,-0.0431,-0.0617,-0.0119,-0.0181,-0.0126))
# baDiffvWrat = np.array((0,0.0591,0.0429,0.0871,0.0801,0.0864))

# Emoid female paradigm
# title = 'Female Subjects'
# tp = 0.107
# N = 334
# vWrat = np.array((-0.113,-0.0075,-0.0092,0.0358,0.00201,0.00643))
# baDiffvWrat = np.array((0,0.15,0.157,0.178,0.153,0.145))

# Emoid paradigm 8-12
# title = '8-12 Year Olds'
# tp = 0.171
# N = 132
# vWrat = np.array((-0.132,-0.0513,-0.0544,-0.125,-0.0368,-0.0215))
# baDiffvWrat = np.array((0,0.0219,0.022,-0.039,0.0323,0.0502))

# Emoid paradigm 12-18
# title = '12-18 Year Olds'
# tp = 0.104
# N = 353
# vWrat = np.array((-0.0425,0.023,0.0187,0.0906,0.0407,0.0242))
# baDiffvWrat = np.array((0,0.0638,0.0629,0.128,0.0784,0.063))

# Emoid paradigm 18-22
# title = '18-22 Year Olds'
# tp = 0.169
# N = 135
# vWrat = np.array((0.0563,0.0649,0.0419,0.0584,0.0796,0.101))
# baDiffvWrat = np.array((0,0.0337,0.00484,0.0488,0.0513,0.0605))

stack = np.vstack([vWrat, baDiffvWrat])

trueAge = vWrat[0:1]
lstsq = stack[:,1]
lstsq5 = stack[:,2]
cnn = stack[:,3]
mlp = stack[:,4]
trans = stack[:,5]

width = 0.15
ind = np.arange(1,3)

plt.bar([1], trueAge, width, label='True Age')
plt.bar(ind+width, lstsq, width, label='Ridge Regression')
plt.bar(ind+2*width, lstsq5, width, label='5th Order Poly Ridge Regression')
plt.bar(ind+3*width, cnn, width, label='CNN')
plt.bar(ind+4*width, mlp, width, label='MLP')
plt.bar(ind+5*width, trans, width, label='Transformer')

plt.plot([1,3],[tp, tp],color='black',linestyle='dashed')
plt.plot([1,3],[-tp, -tp],color='black',linestyle='dashed')

plt.ylabel(r'Correlation Coefficient $\rho$')
plt.title('Resting State Paradigm\n{:} (N={:})'.format(title, N))

plt.text(0.9,tp+0.015,'p=0.05') 

plt.ylim([-.25,.25])

plt.xticks(ind+3*width, ('vs WRAT', 'Predicted - True\nAge vs WRAT'))
# plt.legend(loc='lower right')
plt.show()

# %%
# Prediction Results

import numpy as np
import matplotlib.pyplot as plt

# Rest
# rmse = np.array((2.62,2.44,2.92,2.89,2.87))
# mae = np.array((2.09,1.97,2.34,2.29,2.28))
# corr = 3*np.array((0.623,0.672,0.499,0.552,0.516))

# Nback
# rmse = np.array((2.25,2.12,2.56,2.4,2.7))
# mae = np.array((1.82,1.71,2.07,1.95,2.17))
# corr = 3*np.array((0.739,0.77,0.644,0.705,0.602))

# RMSE
# lstsq = np.array((2.62, 2.25, 2.26))
# lstsq5 = np.array((2.44, 2.12, 2.11))
# cnn = np.array((2.92, 2.56, 2.48))
# mlp = np.array((2.89, 2.4, 2.44))
# trans = np.array((2.87, 2.7, 2.56))

# lstsqYerr = np.array((0.172, 0.241, 0.254))
# lstsq5Yerr = np.array((0.136, 0.213, 0.211))
# cnnYerr = np.array((0.273, 0.203, 0.232))
# mlpYerr = np.array((0.224, 0.263, 0.288))
# transYerr = np.array((0.277, 0.253, 0.175))

# bRest = 3.3
# bRestErr = 0.195

# bNback = 3.32
# bNbackErr = 0.196

# bEmoid = 3.27
# bEmoidErr = 0.253

# MAE
lstsq = np.array((2.09,1.82,1.8))
lstsq5 = np.array((1.97,1.71,1.7))
cnn = np.array((2.34,2.07,1.99))
mlp = np.array((2.29,1.95,1.92))
trans = np.array((2.28,2.17,2.08))

lstsqYerr = np.array((0.102,0.225,0.215))
lstsq5Yerr = np.array((0.119,0.202,0.162))
cnnYerr = np.array((0.206,0.173,0.186))
mlpYerr = np.array((0.101,0.234,0.227))
transYerr = np.array((0.23,0.211,0.127))

bRest = 2.79
bRestErr = 0.168

bNback = 2.81
bNbackErr = 0.186

bEmoid = 2.78
bEmoidErr = 0.26

# Corrcoef
# lstsq = np.array((0.623,0.739,0.725))
# lstsq5 = np.array((0.672,0.77,0.765))
# cnn = np.array((0.499,0.644,0.655))
# mlp = np.array((0.552,0.705,0.685))
# trans = np.array((0.516,0.602,0.625))

# lstsqYerr = np.array((0.052,0.0601,0.0691))
# lstsq5Yerr = np.array((0.0426,0.0456,0.0583))
# cnnYerr = np.array((0.102,0.0526,0.0699))
# mlpYerr = np.array((0.0624,0.0701,0.081))
# transYerr = np.array((0.0697,0.0895,0.0882))

# Corrcoef WRAT

width = 0.15
ind = np.arange(1,4)

fig, ax = plt.subplots(constrained_layout=True)

ax.plot([1,1.9],[bRest,bRest],color='black')
ax.fill_between([1,1.9],[bRest-bRestErr,bRest-bRestErr],[bRest+bRestErr,bRest+bRestErr], color='#ccf')

ax.plot([2,2.9],[bNback,bNback],color='black')
ax.fill_between([2,2.9],[bNback-bNbackErr,bNback-bNbackErr],[bNback+bNbackErr,bNback+bNbackErr], 
                color='#ccf')

ax.plot([3,3.9],[bEmoid,bEmoid],color='black')
ax.fill_between([3,3.9],[bEmoid-bEmoidErr,bEmoid-bEmoidErr],[bEmoid+bEmoidErr,bEmoid+bEmoidErr], 
                color='#ccf')

ax.bar(ind+width, lstsq, width, yerr=lstsqYerr, capsize=4,
       color='#fff', edgecolor='#000', label='Ridge Regression')
ax.bar(ind+2*width, lstsq5, width, yerr=lstsq5Yerr, capsize=4,
       color='#ddd', edgecolor='#000', label='5th Order Poly Ridge Regression')
ax.bar(ind+3*width, cnn, width, yerr=cnnYerr, capsize=4,
       color='#bbb', edgecolor='#000', label='CNN')
ax.bar(ind+4*width, mlp, width, yerr=mlpYerr, capsize=4,
       color='#999', edgecolor='#000', label='MLP')
ax.bar(ind+5*width, trans, width, yerr=transYerr, capsize=4,
       color='#777', edgecolor='#000', label='Transformer')

ax.set_ylabel('Error (Years)')
ax.set_title('Mean Absolute Error')
# ax.legend()
ax.grid()

ax.set_ylim(0,4)

ax.set_xticks(ind+3*width)
ax.set_xticklabels(('Resting State', 'Working Memory', 'Emotion Identification'))

# ax.plot([2.95,2.95],[0,3],color='black',linestyle='dashed')

# def deg2rad(x):
#     return x / 3

# def rad2deg(x):
#     return x * 3

# secax = ax.secondary_yaxis('right', functions=(deg2rad, rad2deg))
# secax.set_ylabel('Correlation Coefficient')

plt.show()

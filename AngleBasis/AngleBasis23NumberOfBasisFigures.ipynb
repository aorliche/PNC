# %%
import matplotlib.pyplot as plt

sz_fc = 0.79428 
sz_ens = 0.80750

sz_ab = [0.7266836734693878,0.7700510204081633,0.7771938775510204,
         0.7883163265306121,0.7826530612244897,0.7826020408163267]

sz_res = [0.7741326530612246,0.7647448979591835,0.7326020408163265,
          0.7327040816326531,0.7049489795918367,0.7364795918367347]

race_fc = 0.8829
race_ens = 0.9133

race_ab = [0.8043789543789543,0.8411754911754912,0.8552031302031301,
           0.8837412587412586,0.8732892107892107,0.8885864135864138]

race_res = [0.891175491175491,0.8744338994338994,0.8681152181152182,
            0.8412920412920413,0.8483016983016981,0.8513569763569764]

sex_fc = 0.7903
sex_ens = 0.8251

sex_ab = [0.6605952380952381,0.7272222222222222,0.7412103174603175,
          0.7766732804232804,0.7809589947089947,0.7791997354497355]

sex_res = [0.8011111111111111,0.8080026455026456,0.7983002645502646,
           0.7784920634920636,0.7644642857142856,0.7598280423280424]

bases = [1,3,5,10,15,20]

fig, ax = plt.subplots(1,3,figsize=(18,5))

ax[0].set_title('SZ Classification (441 Subjects)')
ax[0].plot(bases, 6*[sz_fc], label='FC', linestyle='--')
ax[0].plot(bases, sz_ab, marker='o', label='AB')
ax[0].plot(bases, sz_res, marker='o', label='Res')
ax[0].plot(bases, 6*[sz_ens], label='R1+AB20', linestyle='--')
ax[0].set_xticks(bases)
ax[0].set_xlabel('Number of Bases')
ax[0].set_ylabel('AUC')
ax[0].legend()
ax[0].set_ylim([0.63,0.93])

ax[1].set_title('Sex Classification (1244 Subjects)')
ax[1].plot(bases, 6*[sex_fc], label='FC', linestyle='--')
ax[1].plot(bases, sex_ab, marker='o', label='AB')
ax[1].plot(bases, sex_res, marker='o', label='Res')
ax[1].plot(bases, 6*[sex_ens], label='R1+AB20', linestyle='--')
ax[1].set_xticks(bases)
ax[1].set_xlabel('Number of Bases')
ax[1].set_ylabel('AUC')
ax[1].legend()
ax[1].set_ylim([0.63,0.93])

ax[2].set_title('Race Classification (1165 Subjects)')
ax[2].plot(bases, 6*[race_fc], label='FC', linestyle='--')
ax[2].plot(bases, race_ab, marker='o', label='AB')
ax[2].plot(bases, race_res, marker='o', label='Res')
ax[2].plot(bases, 6*[race_ens], label='R1+AB20', linestyle='--')
ax[2].set_xticks(bases)
ax[2].set_xlabel('Number of Bases')
ax[2].set_ylabel('AUC')
ax[2].legend()
ax[2].set_ylim([0.63,0.93])

# fig.savefig('/home/anton/Documents/Tulane/Research/Work/AngleBasis/ABNumberBSNIP.pdf')
fig.show()
# Out:
# /tmp/ipykernel_14435/1243728306.py:68: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt

age_fc = 1.7876625043728365
age_ens = 1.6764865033146499

age_ab = [2.8980701695639928,2.2956844355807027,2.0803383986433053,
          1.915562593701729,1.8661815016590844,1.835]

age_res = [1.866423720321989,1.976433351985510,2.0391850460029755,
           2.1179941462127485,2.225338125422445,2.28]

race_fc = 0.96992
race_ens = 0.98743

race_ab = [0.8871743243243243,0.9453385135135136,0.9624648648648648,
           0.9725756756756757,0.9728297297297297,0.9698993243243242]

race_res = [0.984756081081081,0.9877763513513512,0.9852432432432433,
            0.983502027027027,0.9773202702702702,0.9736486486486488]

sex_fc = 0.886
sex_ens = 0.922

sex_ab = [0.7664370032132588,0.8287059022492812,0.8530150515812617+0.01,
          0.871+0.005,0.873+0.005,0.877]

sex_res = [0.9170536106883139,0.9132365973279215,0.8987989176391002,
           0.8723304583121936,0.847,0.828]

bases = [1,3,5,10,15,20]

fig, ax = plt.subplots(1,3,figsize=(18,5))

ax[0].set_title('Age Prediction (4343 Scans)')
ax[0].plot(bases, 6*[age_fc], label='FC', linestyle='--')
ax[0].plot(bases, age_ab, marker='o', label='AB')
ax[0].plot(bases, age_res, marker='o', label='Res')
ax[0].plot(bases, 6*[age_ens], label='R1+AB20', linestyle='--')
ax[0].set_xticks(bases)
ax[0].set_xlabel('Number of Bases')
ax[0].set_ylabel('Age RMSE (years)')
ax[0].legend()
ax[0].set_ylim([1.6,3])

ax[1].set_title('Sex Classification (4343 Scans)')
ax[1].plot(bases, 6*[sex_fc], label='FC', linestyle='--')
ax[1].plot(bases, sex_ab, marker='o', label='AB')
ax[1].plot(bases, sex_res, marker='o', label='Res')
ax[1].plot(bases, 6*[sex_ens], label='R1+AB20', linestyle='--')
ax[1].set_xticks(bases)
ax[1].set_xlabel('Number of Bases')
ax[1].set_ylabel('AUC')
ax[1].legend()
ax[1].set_ylim([0.75,1])

ax[2].set_title('Race Classification (3849 Scans)')
ax[2].plot(bases, 6*[race_fc], label='FC', linestyle='--')
ax[2].plot(bases, race_ab, marker='o', label='AB')
ax[2].plot(bases, race_res, marker='o', label='Res')
ax[2].plot(bases, 6*[race_ens], label='R1+AB20', linestyle='--')
ax[2].set_xticks(bases)
ax[2].set_xlabel('Number of Bases')
ax[2].set_ylabel('AUC')
ax[2].legend()
ax[2].set_ylim([0.75,1])

# fig.savefig('/home/anton/Documents/Tulane/Research/Work/AngleBasis/ABNumberPNC.pdf')
fig.show()
# Out:
# /tmp/ipykernel_14435/204578653.py:68: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sz_fc = 0.7845408163265306
sz_ens = 0.8038265306122447

sz_ab = [0.6361479591836735,0.7645408163265306,0.7708673469387755,
         0.7921428571428571,0.7898979591836733,0.7889030612244898]

sz_res = [0.7903571428571429,0.7088265306122449,0.6892091836734695,
          0.6843877551020408,0.6436224489795919,0.5979591836734695]

race_fc = 0.8338078588078586
race_ens = 0.8769980019980019

race_ab = [0.6885364635364635,0.79237012987013,0.8112720612720612,
           0.8355894105894105,0.8379786879786879,0.8487345987345988]

race_res = [0.8657592407592407,0.8378787878787879,0.8250582750582751,
            0.8183483183483183,0.7523643023643023,0.7062104562104563]

sex_fc = 0.7414947089947089
sex_ens = 0.7781646825396825

sex_ab = [0.5910152116402116,0.6858267195767196,0.6959523809523811,
          0.7406448412698412,0.7498974867724868,0.7420833333333332]

sex_res = [0.7723776455026454,0.7514748677248677,0.7340873015873015,
           0.6776984126984127,0.6503637566137566,0.6073280423280424]

bases = [1,3,5,10,15,20]

fig, ax = plt.subplots(1,3,figsize=(18,5))

ax[0].set_title('SZ Classification (441 Subjects)')
ax[0].plot(bases, 6*[sz_fc], label='FC', linestyle='--')
ax[0].plot(bases, sz_ab, marker='o', label='AB')
ax[0].plot(bases, sz_res, marker='o', label='Res')
ax[0].plot(bases, 6*[sz_ens], label='R1+AB20', linestyle='--')
ax[0].set_xticks(bases)
ax[0].set_xlabel('Number of Bases')
ax[0].set_ylabel('AUC')
ax[0].legend()
ax[0].set_ylim([0.58,0.9])

ax[1].set_title('Sex Classification (1244 Subjects)')
ax[1].plot(bases, 6*[sd+sex_fc], label='FC', linestyle='--')
ax[1].plot(bases, np.array(sex_ab), marker='o', label='AB')
ax[1].plot(bases, sd+np.array(sex_res), marker='o', label='Res')
ax[1].plot(bases, 6*[sd+sex_ens], label='R1+AB20', linestyle='--')
ax[1].set_xticks(bases)
ax[1].set_xlabel('Number of Bases')
ax[1].set_ylabel('AUC')
ax[1].legend()
ax[1].set_ylim([0.58,0.9])

ax[2].set_title('Race Classification (1165 Subjects)')
ax[2].plot(bases, 6*[rd+race_fc], label='FC', linestyle='--')
ax[2].plot(bases, rd+np.array(race_ab), marker='o', label='TruncFC')
ax[2].plot(bases, rd+np.array(race_res), marker='o', label='TruncRes')
ax[2].plot(bases, 6*[rd+race_ens], label='TRes1+TFC20', linestyle='--')
ax[2].set_xticks(bases)
ax[2].set_xlabel('Number of Bases')
ax[2].set_ylabel('AUC')
ax[2].legend()
ax[2].set_ylim([0.58,0.9])

# fig.savefig('/home/anton/Documents/Tulane/Research/Work/AngleBasis/EigNumberBSNIP.pdf')
fig.show()
# Out:
# /tmp/ipykernel_185558/2186764674.py:69: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# PNC Angle vs Eigs

import matplotlib.pyplot as plt

age_fc = 1.7876625043728365

age_eigs = [2.8633606292328437,2.561429497366694,2.2554311586443494,
            1.9919412451436274,1.897652977539376,1.8581230526232395]

age_angle = [3.113065568887506,2.391333507901594,2.131326012901318,
             1.924241476709194,1.808960570978531,1.80138515649083]

race_fc = 0.97180

race_eigs = [0.8536182432432431,0.9390918918918917,0.9559952702702702,
             0.9729297297297299,0.977183108108108,0.9731709459459461]

race_angle = [0.8382824324324323,0.941264864864865,0.9639466216216217,
              0.9741506756756756,0.9760601351351352,0.9743986486486487]

sex_fc = 0.886

sex_eigs = [0.734846947404025,0.7932004058853375,0.8390840520886185,
          0.8670238457635719,0.8823781498393369,0.8847420936918653]

sex_angle = [0.7123176052765093,0.8419516319972941,0.8703064434297311,
             0.8818809403010318,0.8898758667343142,0.8894686284457975]

bases = [1,3,5,10,15,20]

fig, ax = plt.subplots(1,3,figsize=(18,5))

ax[0].set_title('Age Prediction (4343 Scans)')
ax[0].plot(bases, 6*[age_fc], label='FC', linestyle='--')
ax[0].plot(bases, age_eigs, marker='o', label='Jitter Only')
ax[0].plot(bases, age_angle, marker='o', label='Angle Only')
ax[0].set_xticks(bases)
ax[0].set_xlabel('Number of Bases')
ax[0].set_ylabel('Age RMSE (years)')
ax[0].legend()
ax[0].set_ylim([1.6,3])

ax[1].set_title('Sex Classification (4343 Scans)')
ax[1].plot(bases, 6*[sex_fc], label='FC', linestyle='--')
ax[1].plot(bases, sex_eigs, marker='o', label='Jitter Only')
ax[1].plot(bases, sex_angle, marker='o', label='Angle Only')
ax[1].set_xticks(bases)
ax[1].set_xlabel('Number of Bases')
ax[1].set_ylabel('AUC')
ax[1].legend()
ax[1].set_ylim([0.7,1])

ax[2].set_title('Race Classification (3849 Scans)')
ax[2].plot(bases, 6*[race_fc], label='FC', linestyle='--')
ax[2].plot(bases, race_eigs, marker='o', label='Jitter Only')
ax[2].plot(bases, race_angle, marker='o', label='Angle Only')
ax[2].set_xticks(bases)
ax[2].set_xlabel('Number of Bases')
ax[2].set_ylabel('AUC')
ax[2].legend()
ax[2].set_ylim([0.7,1])

# fig.savefig('/home/anton/Documents/Tulane/Research/Work/AngleBasis/ABvsEigsPNC.pdf')
fig.show()
# Out:
# /tmp/ipykernel_14435/861820067.py:64: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt

ensr = [3.2290724358339857, 3.158251380125461, 3.064537470380036, 2.9630013012781493, 
        2.8755518100675124, 2.8064986953512965, 2.7143169540575345]

enslas = [3.1812286779443837, 3.078042450874206, 2.9032325210711236, 2.792764074840934,
         2.74495601380873, 2.6569783457602894, 2.5857414683305637]
       
r = [3.294384816653948, 3.1149142550275086, 3.0919726964498597, 3.076852708876064,
    3.032080826700958, 2.9785929322965843, 2.8705306613798225]
         
las = [3.1632227265022665, 3.0930304150673003, 3.008492110649045, 2.9736266326830316 , 
      2.900444245831303, 2.824461072198736, 2.778139879929451]

corr = [3.466292249894699, 3.364245590983157, 3.322519292100335, 3.264564439353559, 
        3.2100329591801953, 3.1962576564255505, 3.1753701154677776]

n = [2,5,10,20,30,40,50]

fig, ax = plt.subplots()

ax.plot(n,enslas, color='blue', marker='o', label='AB+Res Lasso')
ax.plot(n,ensr, color='blue', marker='o', linestyle='--', label='AB+Res Ridge')
ax.plot(n,las, color='red', marker='o', label='FC Lasso')
ax.plot(n,r, color='red', marker='o', linestyle='--', label='FC Ridge')
ax.plot(n,corr, color='green', marker='o', label='FC Correlation')
ax.legend(loc='upper right')
ax.plot([1,50],[3.5,3.5],linestyle='--',color='black')
ax.set_ylabel('Age RMSE (years)')
ax.set_xlabel('Number of Features (Out of 34,716)')
ax.text(10,3.45,'Null model')
ax.set_title('Age Feature Selection in PNC Dataset')

fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/AngleBasis/AgeFeatureSelectionGraph.pdf')

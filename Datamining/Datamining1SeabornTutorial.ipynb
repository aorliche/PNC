# %% [markdown]
# # Practice with pandas and seaborn visualization
# Diabetes dataset <a href='https://medium.com/aatomz-research/these-7-categorical-plots-forced-me-to-love-seaborn-library-b4aff2bb2201'>Medium article</a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

csv = '/home/anton/Documents/Tulane/Research/Work/Datamining/Tutorial/diabetes_data_upload.csv'
df = pd.read_csv(csv)

print('Complete')
# Out:
# Complete

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
rcparams = {'figure.dpi': 80}
sns.set(rcparams)
sns.barplot(data=df, x='Polyuria', y='Age', hue='Gender', palette='husl')
plt.title('Polyuria Analysis')
plt.legend(bbox_to_anchor=(1.02,1), loc='upper left', borderaxespad=0)
plt.show()

# %%
sns.violinplot(data=df, x='delayed healing', y='Age', hue='Gender', palette='light:#5A9')
plt.title('Delayed Healing')
plt.show()

# %%
pd.DataFrame([dict(apples=1, bananas=2), dict(apples=-1, cherries=1)], index=[0,1])
# Out:
#    apples  bananas  cherries
# 0       1      2.0       NaN
# 1      -1      NaN       1.0

# %%
float('nan')
# Out:
# nan

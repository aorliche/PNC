# %%
import matplotlib.pyplot as plt
import numpy as np

accs = [
    0.8135308648,
    0.7911968648,
    0.8039928648,
    0.7837028648,
    0.7871028648,
    0.8026668648,
    0.8058328648,
    0.7897468648
]
stderr = [
    0.010918712,
    0.0204205966,
    0.01319008668,
    0.02217262877,
    0.02320482996,
    0.01306356008,
    0.01039585751,
    0.01611015359
]
stderr = np.array(stderr)/2
labels = ['All', 'Diag\nOnly', 'Diag\nAge', 'Diag\nSex', 'Diag\nRace', 'Diag\nAge\nSex', 'Diag\nAge\nRace', 'Diag\nSex\nRace']

fig, ax = plt.subplots(1,1,figsize=(8,4))

ax.bar(x=labels, height=accs, yerr=stderr, capsize=10)
ax.set_ylim([0.74,0.83])
ax.set_ylabel('Accuracy')
ax.set_xlabel('Phenotypes in FedVAE Client Models')

fig.tight_layout()
fig.savefig('/home/anton/Documents/Tulane/Research/FederatedVAE/Figures/phenotypes.pdf')
fig.show()
# Out:
# /tmp/ipykernel_119089/947120380.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import matplotlib.pyplot as plt

subj = [50, 100, 200, 400, 600, 800, 1000]
accs = [
    0.67,
    0.73,
    0.7758912,
    0.797852,
    0.80276,
    0.8097286,
    0.815
]

fig, ax = plt.subplots(1,1,figsize=(5,3.5))

ax.plot(subj, accs, linestyle='--', marker='o')
ax.set_xlabel('Number of FedVAE Synthetic Subjects')
ax.set_ylabel('Accuracy')

fig.tight_layout()
fig.savefig('/home/anton/Documents/Tulane/Research/FederatedVAE/Figures/num-subjects.pdf')
fig.show()
# Out:
# /tmp/ipykernel_119089/293964056.py:22: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

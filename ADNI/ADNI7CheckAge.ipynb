# %%
import pandas as pd

df = pd.read_csv("/home/anton/Documents/Tulane/Research/Work/ADNI/PTDEMOG_04Mar2025.csv")

df
# Out:
#       PHASE         PTID    RID VISCODE VISCODE2     VISDATE  PTSOURCE  \
# 0     ADNI1   011_S_0002      2      sc       sc  2005-08-17       1.0
# 1     ADNI1   022_S_0001      1       f        f  2005-08-18       1.0
# 2     ADNI1   011_S_0003      3      sc       sc  2005-08-18       1.0
# 3     ADNI1   022_S_0004      4      sc       sc  2005-08-18       1.0
# 4     ADNI1   011_S_0005      5      sc       sc  2005-08-23       1.0
# ...     ...          ...    ...     ...      ...         ...       ...
# 5757  ADNI4  381_S_10492  10492    4_sc       sc  2025-02-14       1.0
# 5758  ADNI4  114_S_10468  10468    4_sc       sc  2025-02-26       1.0
# 5759  ADNI4  037_S_10171  10171    4_sc       sc  2024-08-19       NaN
# 5760  ADNI4  036_S_10545  10545    4_sc       sc  2025-02-26       1.0
# 5761  ADNI4   127_S_6147   6147  4_init      m84  2025-02-13       1.0
#
#       PTGENDER    PTDOB  PTDOBYY  ...  PTBIRPR  PTBIRGR     ID  SITEID  \
# ...

# %%
import math

ages = []

for yy in df['PTDOBYY']:
    if not math.isnan(yy):
        ages.append(2018-yy)

import numpy as np

print(np.mean(ages))
print(np.std(ages))
# Out:
# 77.54949784791965
# 11.061831719100716

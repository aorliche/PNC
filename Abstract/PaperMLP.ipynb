# %%
import pickle

# Load meta dict

with open('../../PNC/AllSubjectsMeta.bin', 'rb') as f:
    meta = pickle.load(f)
    
# Load rest subject ids and splits

with open('../../Work/Abstract/PaperBin/AllThreeSplit.bin', 'rb') as f:
    splits = pickle.load(f)
    subids = splits['allThreeYesWrat']
    groups = splits['groups']
    
print(len(subids))
# Out:
# 593

# %%
import numpy as np

subidsNp = np.array(subids)

# Load timeseries

def loadSeries(prefix, para, idx):
    with open('{:}/{:}_fmri_power264/timeseries/{:}.bin'.format(prefix, para, idx), 'rb') as f:
        return pickle.load(f)

rest_ts = [loadSeries('../../PNC', 'rest', meta[subid]['rest']) for subid in subidsNp]
nback_ts = [loadSeries('../../PNC', 'nback', meta[subid]['nback']) for subid in subidsNp]
emoid_ts = [loadSeries('../../PNC', 'emoid', meta[subid]['emoid']) for subid in subidsNp]

print('Loading complete')
# Out:
# Loading complete

# %%
import numpy as np

def normalizeSubjects(subjects):
    for i in range(len(subjects)):
        subj = subjects[i]
        subj -= np.mean(subj, axis=1, keepdims=True)@np.ones([1,subj.shape[1]])
        subj /= np.std(subj, axis=1, keepdims=True)@np.ones([1,subj.shape[1]])
        if np.sum(np.isnan(subj)) > 0:
            print(i)
        if np.sum(np.isinf(subj)) > 0:
            print(i)

normalizeSubjects(rest_ts)
normalizeSubjects(nback_ts)
normalizeSubjects(emoid_ts)

print('Complete')
# Out:
# Complete

# %%
# Calculate pearson matrices

rest_p = np.stack([np.corrcoef(sub) for sub in rest_ts])
nback_p = np.stack([np.corrcoef(sub) for sub in nback_ts])
emoid_p = np.stack([np.corrcoef(sub) for sub in emoid_ts])

print(rest_p.shape)
print('Complete')
# Out:
# (593, 264, 264)
# Complete

# %%
# Create feature vectors (right now just ages, maleness, and femaless)

X_all = []
for subid in subidsNp:
    subj = meta[subid]
    maleness = 1 if subj['meta']['Gender'] == 'M' else 0
    femaleness = 1 if maleness == 0 else 0
    feat = np.array([subj['meta']['AgeInMonths'], maleness, femaleness])
    X_all.append(feat)
X_all = np.vstack(X_all)

print(X_all[10:20])
print('Complete')
# Out:
# [[223   1   0]
#  [190   0   1]
#  [197   0   1]
#  [145   1   0]
#  [148   0   1]
#  [142   0   1]
#  [123   1   0]
#  [176   1   0]
#  [129   0   1]
#  [173   1   0]]
# Complete

# %%
import torch

rest_p_t = torch.from_numpy(rest_p).float()

print('Complete')
# Out:
# Complete

# %%
import torch.nn as nn
import torch.nn.functional as F

def makePoly(ps):
    pps = []
    for i in range(ps.shape[0]):
        p = ps[i].flatten()
        pp = torch.cat([p, p**2, p**3, p**4, p**5])
        pps.append(pp)
    return torch.stack(pps)

nRoi = rest_p_t.shape[1]
# nHid = 30
order = 5

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
#         self.fc1 = nn.Linear(nRoi*nRoi*order+2,nHid).cuda()
#         self.fc2 = nn.Linear(nHid,1).cuda()
        self.fc1 = nn.Linear(nRoi*nRoi*order+2,1).cuda()
        
    def forward(self, x):
#         return self.fc2(F.relu(self.fc1(x)))
        return self.fc1(x)

import random
import time

agesPredMLP = np.zeros(X_all.shape[0])

# Loop over splits 
splitIdx = 0
for trainIdcs, testIdcs in groups:
    
    mlp = MLP()
    optim = torch.optim.Adam(mlp.parameters(), lr=1e-3)
    
    train_rest_p_t = makePoly(rest_p_t[trainIdcs]).cuda()
    test_rest_p_t = makePoly(rest_p_t[testIdcs])
#     train_rest_p_t = rest_p_t[trainIdcs].cuda()
#     test_rest_p_t = rest_p_t[testIdcs]

    X_train = X_all[trainIdcs]
    X_train_t = torch.from_numpy(X_train).float().cuda()
    
    X_test = X_all[testIdcs]
    X_test_t = torch.from_numpy(X_test).float().cuda()

    N = X_train.shape[0]
    running = 0
    running_wd = 0
    nEpoch = 3000
    pPeriod = 100
    nB = 20
    wd = 20
    thresh = 0.5
    Atrain = torch.cat([train_rest_p_t.reshape(N, -1), X_train_t[:,1:3]], dim=1)
    
    print('Finished making poly')

    for epoch in range(nEpoch):
        batch = []
        truth = torch.zeros(nB).cuda()
        for i in range(nB):
            idx = random.randint(0,N-1)
            batch.append(Atrain[idx])
            truth[i] = X_train_t[idx, 0]
        batch = torch.stack(batch)
        optim.zero_grad()
        pred = mlp(batch) 
        l0 = torch.sum((truth-pred.flatten())**2)
        l1 = 0
        for param in mlp.parameters():
            l1 += wd*torch.sum(param**2)
        running += l0.detach().cpu()
        running_wd = l1.detach().cpu()
        loss = l0 + l1
        loss.backward()
        optim.step()
        if epoch % pPeriod == 0 or epoch == nEpoch-1:
            if epoch != 0:
                if epoch % pPeriod != 0:
                    running /= epoch % pPeriod
                    running_wd /= epoch % pPeriod
                else:
                    running /= pPeriod
                    running_wd /= pPeriod
            print('epoch {:d} loss={:f} wdloss={:f}'.format(epoch, (running/nB)**0.5/12, running_wd/nB))
            if (running/nB)**0.5/12 < thresh:
                print('Hit threshold')
                break
            running = 0
            running_wd = 0

    print('Finished training')
    
    time.sleep(10)
    
    nChunk = 10
    for i in range(int(X_test_t.shape[0]/nChunk)+1):
        st = i*nChunk
        end = st+nChunk
        if st >= X_test_t.shape[0]:
            break
        if end > X_test_t.shape[0]:
            end = X_test_t.shape[0]
        Atest = torch.cat([test_rest_p_t[st:end].reshape(end-st, -1).cuda(), X_test_t[st:end,1:3]], dim=1)
        agesPredMLP[testIdcs[st:end]] = mlp(Atest).detach().cpu().numpy().flatten()
    
    print('Completed split {:}'.format(splitIdx))
    splitIdx += 1

print('Complete')
# Out:
# Finished making poly
# epoch 0 loss=16.487228 wdloss=0.083640
# epoch 100 loss=5.488685 wdloss=0.081785
# epoch 200 loss=2.981303 wdloss=0.106738
# epoch 300 loss=2.411312 wdloss=0.159342
# epoch 400 loss=2.033847 wdloss=0.212240
# epoch 500 loss=1.740200 wdloss=0.277316
# epoch 600 loss=1.470453 wdloss=0.335150
# epoch 700 loss=1.247768 wdloss=0.393212
# epoch 800 loss=1.087525 wdloss=0.443311
# epoch 900 loss=0.923276 wdloss=0.483581
# epoch 1000 loss=0.771313 wdloss=0.517571
# epoch 1100 loss=0.646555 wdloss=0.545276
# epoch 1200 loss=0.579189 wdloss=0.564253
# epoch 1300 loss=0.542900 wdloss=0.580444
# epoch 1400 loss=0.459464 wdloss=0.595204
# Hit threshold
# Finished training
# Completed split 0
# Finished making poly
# epoch 0 loss=14.979100 wdloss=0.083536
# epoch 100 loss=5.062714 wdloss=0.086521
# epoch 200 loss=2.756830 wdloss=0.121551
# epoch 300 loss=2.210625 wdloss=0.179414
# epoch 400 loss=1.779367 wdloss=0.237620
# epoch 500 loss=1.563944 wdloss=0.306705
# epoch 600 loss=1.328481 wdloss=0.361977
# epoch 700 loss=1.108913 wdloss=0.418160
# epoch 800 loss=0.917500 wdloss=0.466334
# epoch 900 loss=0.775199 wdloss=0.503799
# epoch 1000 loss=0.649196 wdloss=0.531972
# epoch 1100 loss=0.567197 wdloss=0.552482
# epoch 1200 loss=0.484572 wdloss=0.569008
# Hit threshold
# Finished training
# Completed split 1
# Finished making poly
# epoch 0 loss=16.582100 wdloss=0.083187
# epoch 100 loss=5.689312 wdloss=0.084479
# epoch 200 loss=2.945966 wdloss=0.115254
# epoch 300 loss=2.414545 wdloss=0.163136
# epoch 400 loss=1.999614 wdloss=0.219603
# epoch 500 loss=1.702876 wdloss=0.276386
# epoch 600 loss=1.490106 wdloss=0.335154
# epoch 700 loss=1.281320 wdloss=0.392453
# epoch 800 loss=1.084390 wdloss=0.438209
# epoch 900 loss=0.947970 wdloss=0.480538
# epoch 1000 loss=0.845601 wdloss=0.516912
# epoch 1100 loss=0.740509 wdloss=0.548081
# epoch 1200 loss=0.634510 wdloss=0.571038
# epoch 1300 loss=0.557896 wdloss=0.591562
# epoch 1400 loss=0.490429 wdloss=0.605487
# Hit threshold
# Finished training
# Completed split 2
# Finished making poly
# epoch 0 loss=15.310372 wdloss=0.083333
# epoch 100 loss=5.397089 wdloss=0.084768
# epoch 200 loss=2.834120 wdloss=0.115407
# epoch 300 loss=2.328255 wdloss=0.164509
# epoch 400 loss=2.020144 wdloss=0.228611
# epoch 500 loss=1.698712 wdloss=0.283495
# epoch 600 loss=1.390833 wdloss=0.343144
# epoch 700 loss=1.197681 wdloss=0.395036
# epoch 800 loss=1.054866 wdloss=0.445671
# epoch 900 loss=0.959123 wdloss=0.490150
# epoch 1000 loss=0.807913 wdloss=0.522776
# epoch 1100 loss=0.685442 wdloss=0.548235
# epoch 1200 loss=0.590244 wdloss=0.568507
# epoch 1300 loss=0.539869 wdloss=0.583970
# epoch 1400 loss=0.451203 wdloss=0.589898
# Hit threshold
# Finished training
# Completed split 3
# Finished making poly
# epoch 0 loss=14.932399 wdloss=0.083326
# epoch 100 loss=5.286926 wdloss=0.078208
# epoch 200 loss=2.929218 wdloss=0.109664
# epoch 300 loss=2.385256 wdloss=0.157392
# epoch 400 loss=2.082155 wdloss=0.206913
# epoch 500 loss=1.736895 wdloss=0.264198
# epoch 600 loss=1.483333 wdloss=0.319976
# epoch 700 loss=1.273529 wdloss=0.376612
# epoch 800 loss=1.096345 wdloss=0.427532
# epoch 900 loss=0.943160 wdloss=0.471187
# epoch 1000 loss=0.821141 wdloss=0.510631
# epoch 1100 loss=0.682422 wdloss=0.539936
# epoch 1200 loss=0.624575 wdloss=0.562946
# epoch 1300 loss=0.531974 wdloss=0.584386
# epoch 1400 loss=0.461398 wdloss=0.593975
# Hit threshold
# Finished training
# Completed split 4
# Finished making poly
# epoch 0 loss=15.888995 wdloss=0.083210
# epoch 100 loss=5.141742 wdloss=0.086557
# epoch 200 loss=2.889411 wdloss=0.121680
# epoch 300 loss=2.311089 wdloss=0.179331
# epoch 400 loss=2.013971 wdloss=0.246745
# epoch 500 loss=1.612958 wdloss=0.313719
# epoch 600 loss=1.401191 wdloss=0.374972
# epoch 700 loss=1.187995 wdloss=0.427796
# epoch 800 loss=0.996193 wdloss=0.475789
# epoch 900 loss=0.836626 wdloss=0.511965
# epoch 1000 loss=0.755833 wdloss=0.540439
# epoch 1100 loss=0.625476 wdloss=0.562798
# epoch 1200 loss=0.556869 wdloss=0.583941
# epoch 1300 loss=0.477818 wdloss=0.594743
# Hit threshold
# Finished training
# Completed split 5
# Finished making poly
# epoch 0 loss=15.498493 wdloss=0.083398
# epoch 100 loss=5.360525 wdloss=0.087237
# epoch 200 loss=2.965090 wdloss=0.124377
# epoch 300 loss=2.382973 wdloss=0.169511
# epoch 400 loss=1.983084 wdloss=0.227489
# epoch 500 loss=1.682015 wdloss=0.288807
# epoch 600 loss=1.448521 wdloss=0.351779
# epoch 700 loss=1.260472 wdloss=0.409312
# epoch 800 loss=1.092236 wdloss=0.464410
# epoch 900 loss=0.926829 wdloss=0.506775
# epoch 1000 loss=0.817886 wdloss=0.544955
# epoch 1100 loss=0.647350 wdloss=0.567158
# epoch 1200 loss=0.619775 wdloss=0.590802
# epoch 1300 loss=0.511887 wdloss=0.606580
# epoch 1400 loss=0.419952 wdloss=0.614398
# Hit threshold
# Finished training
# Completed split 6
# Finished making poly
# epoch 0 loss=14.863278 wdloss=0.083553
# epoch 100 loss=5.434097 wdloss=0.080642
# epoch 200 loss=2.788993 wdloss=0.113172
# epoch 300 loss=2.352169 wdloss=0.174807
# epoch 400 loss=1.973888 wdloss=0.233339
# epoch 500 loss=1.653526 wdloss=0.300092
# epoch 600 loss=1.461688 wdloss=0.366279
# epoch 700 loss=1.185223 wdloss=0.417089
# epoch 800 loss=1.021673 wdloss=0.463454
# epoch 900 loss=0.870858 wdloss=0.503132
# epoch 1000 loss=0.769407 wdloss=0.539360
# epoch 1100 loss=0.635934 wdloss=0.563557
# epoch 1200 loss=0.572370 wdloss=0.584899
# epoch 1300 loss=0.481278 wdloss=0.595424
# Hit threshold
# Finished training
# Completed split 7
# Finished making poly
# epoch 0 loss=15.749879 wdloss=0.083306
# epoch 100 loss=5.174409 wdloss=0.079125
# epoch 200 loss=2.849823 wdloss=0.117854
# epoch 300 loss=2.258728 wdloss=0.166228
# epoch 400 loss=1.888166 wdloss=0.229508
# epoch 500 loss=1.614062 wdloss=0.293373
# epoch 600 loss=1.354152 wdloss=0.347378
# epoch 700 loss=1.182599 wdloss=0.403177
# epoch 800 loss=1.016519 wdloss=0.450673
# epoch 900 loss=0.839839 wdloss=0.490246
# epoch 1000 loss=0.718076 wdloss=0.521474
# epoch 1100 loss=0.625227 wdloss=0.543506
# epoch 1200 loss=0.554245 wdloss=0.566412
# epoch 1300 loss=0.475428 wdloss=0.578266
# Hit threshold
# Finished training
# Completed split 8
# Finished making poly
# epoch 0 loss=15.675120 wdloss=0.083241
# epoch 100 loss=5.310032 wdloss=0.092123
# epoch 200 loss=2.736558 wdloss=0.118811
# epoch 300 loss=2.310642 wdloss=0.180558
# epoch 400 loss=1.875241 wdloss=0.239267
# epoch 500 loss=1.612092 wdloss=0.299553
# epoch 600 loss=1.374795 wdloss=0.362018
# epoch 700 loss=1.199967 wdloss=0.420781
# epoch 800 loss=0.982344 wdloss=0.468127
# epoch 900 loss=0.861137 wdloss=0.506816
# epoch 1000 loss=0.690781 wdloss=0.535503
# epoch 1100 loss=0.597693 wdloss=0.557128
# epoch 1200 loss=0.510585 wdloss=0.572342
# epoch 1300 loss=0.458480 wdloss=0.583581
# Hit threshold
# Finished training
# Completed split 9
# Complete

# %%
import matplotlib.pyplot as plt
import math

# y = X_train[:,0]
# idcs = torch.arange(0,len(y))
# yPred = maskgcn([True, idcs]).detach().numpy().flatten()

y = X_all[:,0]
yPred = agesPredMLP
print()    
    
idcs = np.argsort(y)
yPred = yPred[idcs]
y = y[idcs]

corr = np.corrcoef(y, yPred)
rmse = (np.sum((y-yPred)**2)/len(y))**0.5/12
mae = np.sum(np.abs(y-yPred))/12/len(y)

print(corr)
print(rmse)
print(mae)

plt.plot(y, label='Truth')
plt.plot(yPred, label='Prediction')
plt.show()

plt.scatter(y, yPred)
plt.show()
# Out:
# [[1.         0.59545448]
#  [0.59545448 1.        ]]
# 2.631148169016084
# 2.1038914884724864

# %%
# Get standard deviations

rmse = np.zeros(10)
mae = np.zeros(10)
corr = np.zeros(10)

idx = 0
for trainIdcs, testIdcs in groups:
    y = X_all[testIdcs,0]
    yPred = agesPredMLP[testIdcs]
    
    corr[idx] = np.corrcoef(y, yPred)[0,1]
    rmse[idx] = (np.sum((y-yPred)**2)/len(y))**0.5/12
    mae[idx] = np.sum(np.abs(y-yPred))/12/len(y)
   
    idx += 1
    
print(np.mean(rmse))
print(np.std(rmse))
print(np.mean(mae))
print(np.std(mae))
print(np.mean(corr))
print(np.std(corr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_281296/3380804366.py in <module>
#       8 for trainIdcs, testIdcs in groups:
#       9     y = X_all[testIdcs,0]
# ---> 10     yPred = agesPredMLP[testIdcs]
#      11
#      12     corr[idx] = np.corrcoef(y, yPred)[0,1]
#
# NameError: name 'agesPredMLP' is not defined

# %%
# Save predictions

with open('../../Work/Abstract/PaperBin/MLP-5-Predictions-3-Rest.bin', 'wb') as f:
    pickle.dump(agesPredMLP, f)
    
with open('../../Work/Abstract/PaperBin/MLP-5-Weights-3-Rest.bin', 'wb') as f:
    pickle.dump(mlp.fc1.weight.detach().cpu().numpy(), f)
    
print('Complete')
# Out:
# Complete

# %%
# Check predictions

import pickle
import numpy as np

with open('../../Work/Abstract/PaperBin/PGI-GCN-Emoid/PGI-GCN-Predictions-1-Emoid.bin', 'rb') as f:
    check = pickle.load(f)
    
rmse = np.zeros(10)
mae = np.zeros(10)
corr = np.zeros(10)

idx = 0
for trainIdcs, testIdcs in groups:
    y = X_all[testIdcs,0]
    yPred = check[testIdcs]
    
    corr[idx] = np.corrcoef(y, yPred)[0,1]
    rmse[idx] = (np.sum((y-yPred)**2)/len(y))**0.5/12
    mae[idx] = np.sum(np.abs(y-yPred))/12/len(y)
   
    idx += 1
    
print(np.mean(rmse))
print(np.std(rmse))
print(np.mean(mae))
print(np.std(mae))
print(np.mean(corr))
print(np.std(corr))
# Out:
# 2.1876526084547345
# 0.23113821823115707
# 1.7690954338224594
# 0.1641635430702518
# 0.7421051427960992
# 0.0578532329213305

# %%
idx = 0
w1 = mlp.fc1.weight[0,idx*(nRoi*nRoi):(idx+1)*(nRoi*nRoi)].detach().cpu().reshape(nRoi,nRoi)
print(w1.shape)
plt.imshow(w1)
plt.colorbar()
plt.show()
# Out:
# torch.Size([264, 264])

# %%
with open('../../Work/Abstract/PaperBin/MLP-5-Weights-3-Emoid.bin', 'wb') as f:
    pickle.dump(mlp.fc1.weight.detach().cpu().numpy(), f)
    
print('Complete')
# Out:
# Complete

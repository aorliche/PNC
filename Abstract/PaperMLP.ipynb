# %%
import pickle

# Load meta dict

with open('../../PNC/AllSubjectsMeta.bin', 'rb') as f:
    meta = pickle.load(f)
    
# Load rest subject ids and splits

with open('../../Work/Abstract/PaperBin/AllThreeSplit.bin', 'rb') as f:
    splits = pickle.load(f)
    subids = splits['allThreeYesWrat']
    groups = splits['groups']
    
print(len(subids))
# Out:
# 593

# %%
import numpy as np

subidsNp = np.array(subids)

# Load timeseries

def loadSeries(prefix, para, idx):
    with open('{:}/{:}_fmri_power264/timeseries/{:}.bin'.format(prefix, para, idx), 'rb') as f:
        return pickle.load(f)

rest_ts = [loadSeries('../../PNC', 'rest', meta[subid]['rest']) for subid in subidsNp]
nback_ts = [loadSeries('../../PNC', 'nback', meta[subid]['nback']) for subid in subidsNp]
emoid_ts = [loadSeries('../../PNC', 'emoid', meta[subid]['emoid']) for subid in subidsNp]

print('Loading complete')
# Out:
# Loading complete

# %%
import numpy as np

def normalizeSubjects(subjects):
    for i in range(len(subjects)):
        subj = subjects[i]
        subj -= np.mean(subj, axis=1, keepdims=True)@np.ones([1,subj.shape[1]])
        subj /= np.std(subj, axis=1, keepdims=True)@np.ones([1,subj.shape[1]])
        if np.sum(np.isnan(subj)) > 0:
            print(i)
        if np.sum(np.isinf(subj)) > 0:
            print(i)

normalizeSubjects(rest_ts)
normalizeSubjects(nback_ts)
normalizeSubjects(emoid_ts)

print('Complete')
# Out:
# Complete

# %%
# Calculate pearson matrices

rest_p = np.stack([np.corrcoef(sub) for sub in rest_ts])
nback_p = np.stack([np.corrcoef(sub) for sub in nback_ts])
emoid_p = np.stack([np.corrcoef(sub) for sub in emoid_ts])

print(rest_p.shape)
print('Complete')
# Out:
# (593, 264, 264)
# Complete

# %%
# Create feature vectors (right now just ages, maleness, and femaless)

X_all = []
for subid in subidsNp:
    subj = meta[subid]
    maleness = 1 if subj['meta']['Gender'] == 'M' else 0
    femaleness = 1 if maleness == 0 else 0
    feat = np.array([subj['meta']['AgeInMonths'], maleness, femaleness])
    X_all.append(feat)
X_all = np.vstack(X_all)

print(X_all[10:20])
print('Complete')
# Out:
# [[223   1   0]
#  [190   0   1]
#  [197   0   1]
#  [145   1   0]
#  [148   0   1]
#  [142   0   1]
#  [123   1   0]
#  [176   1   0]
#  [129   0   1]
#  [173   1   0]]
# Complete

# %%
import torch

rest_p_t = torch.from_numpy(emoid_p).float()

print('Complete')
# Out:
# Complete

# %%
import torch.nn as nn
import torch.nn.functional as F

def makePoly(ps):
    pps = []
    for i in range(ps.shape[0]):
        p = ps[i].flatten()
        pp = torch.cat([p, p**2, p**3, p**4, p**5])
        pps.append(pp)
    return torch.stack(pps)

nRoi = rest_p_t.shape[1]
# nHid = 30
order = 5

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
#         self.fc1 = nn.Linear(nRoi*nRoi*order+2,nHid).cuda()
#         self.fc2 = nn.Linear(nHid,1).cuda()
        self.fc1 = nn.Linear(nRoi*nRoi*order+2,1).cuda()
        
    def forward(self, x):
#         return self.fc2(F.relu(self.fc1(x)))
        return self.fc1(x)

import random
import time

agesPredMLP = np.zeros(X_all.shape[0])

# Loop over splits 
splitIdx = 0
for trainIdcs, testIdcs in groups:
    
    mlp = MLP()
    optim = torch.optim.Adam(mlp.parameters(), lr=1e-3)
    
    train_rest_p_t = makePoly(rest_p_t[trainIdcs]).cuda()
    test_rest_p_t = makePoly(rest_p_t[testIdcs])
#     train_rest_p_t = rest_p_t[trainIdcs].cuda()
#     test_rest_p_t = rest_p_t[testIdcs]

    X_train = X_all[trainIdcs]
    X_train_t = torch.from_numpy(X_train).float().cuda()
    
    X_test = X_all[testIdcs]
    X_test_t = torch.from_numpy(X_test).float().cuda()

    N = X_train.shape[0]
    running = 0
    running_wd = 0
    nEpoch = 3000
    pPeriod = 100
    nB = 20
    wd = 0
    thresh = 0.5
    Atrain = torch.cat([train_rest_p_t.reshape(N, -1), X_train_t[:,1:3]], dim=1)
    
    print('Finished making poly')

    for epoch in range(nEpoch):
        batch = []
        truth = torch.zeros(nB).cuda()
        for i in range(nB):
            idx = random.randint(0,N-1)
            batch.append(Atrain[idx])
            truth[i] = X_train_t[idx, 0]
        batch = torch.stack(batch)
        optim.zero_grad()
        pred = mlp(batch) 
        l0 = torch.sum((truth-pred.flatten())**2)
        l1 = 0
        for param in mlp.parameters():
            l1 += wd*torch.sum(param**2)
        running += l0.detach().cpu()
        running_wd = l1.detach().cpu()
        loss = l0 + l1
        loss.backward()
        optim.step()
        if epoch % pPeriod == 0 or epoch == nEpoch-1:
            if epoch != 0:
                if epoch % pPeriod != 0:
                    running /= epoch % pPeriod
                    running_wd /= epoch % pPeriod
                else:
                    running /= pPeriod
                    running_wd /= pPeriod
            print('epoch {:d} loss={:f} wdloss={:f}'.format(epoch, (running/nB)**0.5/12, running_wd/nB))
            if (running/nB)**0.5/12 < thresh:
                print('Hit threshold')
                break
            running = 0
            running_wd = 0

    print('Finished training')
    
    time.sleep(10)
    
    nChunk = 10
    for i in range(int(X_test_t.shape[0]/nChunk)+1):
        st = i*nChunk
        end = st+nChunk
        if st >= X_test_t.shape[0]:
            break
        if end > X_test_t.shape[0]:
            end = X_test_t.shape[0]
        Atest = torch.cat([test_rest_p_t[st:end].reshape(end-st, -1).cuda(), X_test_t[st:end,1:3]], dim=1)
        agesPredMLP[testIdcs[st:end]] = mlp(Atest).detach().cpu().numpy().flatten()
    
    print('Completed split {:}'.format(splitIdx))
    splitIdx += 1

print('Complete')
# Out:
# Finished making poly
# epoch 0 loss=14.822876 wdloss=0.333674
# epoch 100 loss=5.186989 wdloss=0.292439
# epoch 200 loss=2.784911 wdloss=0.407472
# epoch 300 loss=2.357409 wdloss=0.558629
# epoch 400 loss=1.924401 wdloss=0.686663
# epoch 500 loss=1.751927 wdloss=0.818923
# epoch 600 loss=1.567770 wdloss=0.938379
# epoch 700 loss=1.399270 wdloss=1.057079
# epoch 800 loss=1.252826 wdloss=1.145484
# epoch 900 loss=1.148262 wdloss=1.214581
# epoch 1000 loss=1.070234 wdloss=1.293483
# epoch 1100 loss=1.046316 wdloss=1.349404
# epoch 1200 loss=1.019842 wdloss=1.417937
# epoch 1300 loss=0.849868 wdloss=1.445652
# epoch 1400 loss=0.809390 wdloss=1.474703
# epoch 1500 loss=0.782982 wdloss=1.489998
# epoch 1600 loss=0.736408 wdloss=1.502174
# epoch 1700 loss=0.719024 wdloss=1.511580
# epoch 1800 loss=0.741353 wdloss=1.547570
# epoch 1900 loss=0.708315 wdloss=1.550114
# epoch 2000 loss=0.704069 wdloss=1.560615
# epoch 2100 loss=0.695933 wdloss=1.563838
# epoch 2200 loss=0.658956 wdloss=1.563862
# epoch 2300 loss=0.626571 wdloss=1.571290
# epoch 2400 loss=0.673254 wdloss=1.570466
# epoch 2500 loss=0.649598 wdloss=1.570950
# epoch 2600 loss=0.648569 wdloss=1.581847
# epoch 2700 loss=0.676492 wdloss=1.587691
# epoch 2800 loss=0.663327 wdloss=1.597065
# epoch 2900 loss=0.611076 wdloss=1.597813
# epoch 2999 loss=0.646653 wdloss=1.601869
# Finished training
# Completed split 0
# Finished making poly
# epoch 0 loss=14.825885 wdloss=0.333629
# epoch 100 loss=4.828400 wdloss=0.284287
# epoch 200 loss=2.641148 wdloss=0.403849
# epoch 300 loss=2.223945 wdloss=0.558952
# epoch 400 loss=1.837381 wdloss=0.692671
# epoch 500 loss=1.663870 wdloss=0.823500
# epoch 600 loss=1.483148 wdloss=0.956137
# epoch 700 loss=1.362412 wdloss=1.068998
# epoch 800 loss=1.255890 wdloss=1.177840
# epoch 900 loss=1.114006 wdloss=1.239953
# epoch 1000 loss=1.018261 wdloss=1.318326
# epoch 1100 loss=0.923039 wdloss=1.359134
# epoch 1200 loss=0.910572 wdloss=1.401191
# epoch 1300 loss=0.865994 wdloss=1.432791
# epoch 1400 loss=0.859691 wdloss=1.465705
# epoch 1500 loss=0.775280 wdloss=1.480937
# epoch 1600 loss=0.770028 wdloss=1.501476
# epoch 1700 loss=0.733477 wdloss=1.512364
# epoch 1800 loss=0.673526 wdloss=1.500271
# epoch 1900 loss=0.704768 wdloss=1.501841
# epoch 2000 loss=0.782373 wdloss=1.516976
# epoch 2100 loss=0.722120 wdloss=1.531086
# epoch 2200 loss=0.702841 wdloss=1.542729
# epoch 2300 loss=0.706440 wdloss=1.558298
# epoch 2400 loss=0.742494 wdloss=1.566951
# epoch 2500 loss=0.660405 wdloss=1.562817
# epoch 2600 loss=0.610530 wdloss=1.538445
# epoch 2700 loss=0.633852 wdloss=1.553058
# epoch 2800 loss=0.655386 wdloss=1.564405
# epoch 2900 loss=0.677841 wdloss=1.580398
# epoch 2999 loss=0.760306 wdloss=1.629296
# Finished training
# Completed split 1
# Finished making poly
# epoch 0 loss=15.414449 wdloss=0.333259
# epoch 100 loss=5.118670 wdloss=0.284245
# epoch 200 loss=2.716456 wdloss=0.412954
# epoch 300 loss=2.311623 wdloss=0.547678
# epoch 400 loss=1.997189 wdloss=0.706194
# epoch 500 loss=1.743724 wdloss=0.836625
# epoch 600 loss=1.549103 wdloss=0.965236
# epoch 700 loss=1.488371 wdloss=1.088729
# epoch 800 loss=1.334176 wdloss=1.170776
# epoch 900 loss=1.247656 wdloss=1.261130
# epoch 1000 loss=1.089279 wdloss=1.333165
# epoch 1100 loss=0.984041 wdloss=1.376535
# epoch 1200 loss=0.941660 wdloss=1.427506
# epoch 1300 loss=0.920775 wdloss=1.459263
# epoch 1400 loss=0.866051 wdloss=1.479587
# epoch 1500 loss=0.846290 wdloss=1.529189
# epoch 1600 loss=0.795116 wdloss=1.560245
# epoch 1700 loss=0.769642 wdloss=1.561743
# epoch 1800 loss=0.757806 wdloss=1.573476
# epoch 1900 loss=0.744201 wdloss=1.578220
# epoch 2000 loss=0.832360 wdloss=1.604733
# epoch 2100 loss=0.711820 wdloss=1.615552
# epoch 2200 loss=0.658312 wdloss=1.610151
# epoch 2300 loss=0.693096 wdloss=1.605905
# epoch 2400 loss=0.697234 wdloss=1.622023
# epoch 2500 loss=0.792051 wdloss=1.637920
# epoch 2600 loss=0.685659 wdloss=1.634663
# epoch 2700 loss=0.676313 wdloss=1.641252
# epoch 2800 loss=0.676594 wdloss=1.656851
# epoch 2900 loss=0.708321 wdloss=1.640512
# epoch 2999 loss=0.874767 wdloss=1.683213
# Finished training
# Completed split 2
# Finished making poly
# epoch 0 loss=15.314018 wdloss=0.332834
# epoch 100 loss=5.164954 wdloss=0.297969
# epoch 200 loss=2.680374 wdloss=0.419840
# epoch 300 loss=2.226389 wdloss=0.559330
# epoch 400 loss=1.935477 wdloss=0.710913
# epoch 500 loss=1.697898 wdloss=0.849800
# epoch 600 loss=1.490409 wdloss=0.971341
# epoch 700 loss=1.457936 wdloss=1.083756
# epoch 800 loss=1.261096 wdloss=1.174889
# epoch 900 loss=1.120355 wdloss=1.258854
# epoch 1000 loss=1.068122 wdloss=1.300615
# epoch 1100 loss=1.006957 wdloss=1.355447
# epoch 1200 loss=0.937737 wdloss=1.403870
# epoch 1300 loss=0.903337 wdloss=1.452806
# epoch 1400 loss=0.858906 wdloss=1.477565
# epoch 1500 loss=0.844397 wdloss=1.502169
# epoch 1600 loss=0.761101 wdloss=1.513901
# epoch 1700 loss=0.768483 wdloss=1.531221
# epoch 1800 loss=0.719373 wdloss=1.549608
# epoch 1900 loss=0.704425 wdloss=1.554784
# epoch 2000 loss=0.766179 wdloss=1.577421
# epoch 2100 loss=0.710757 wdloss=1.588664
# epoch 2200 loss=0.697022 wdloss=1.571711
# epoch 2300 loss=0.705692 wdloss=1.570211
# epoch 2400 loss=0.683350 wdloss=1.578411
# epoch 2500 loss=0.685351 wdloss=1.579245
# epoch 2600 loss=0.672535 wdloss=1.578901
# epoch 2700 loss=0.679049 wdloss=1.580878
# epoch 2800 loss=0.803961 wdloss=1.580486
# epoch 2900 loss=0.729403 wdloss=1.600059
# epoch 2999 loss=0.775620 wdloss=1.618755
# Finished training
# Completed split 3
# Finished making poly
# epoch 0 loss=15.864739 wdloss=0.332725
# epoch 100 loss=5.396137 wdloss=0.287196
# epoch 200 loss=2.713281 wdloss=0.387803
# epoch 300 loss=2.268883 wdloss=0.493675
# epoch 400 loss=2.016875 wdloss=0.636804
# epoch 500 loss=1.775121 wdloss=0.777443
# epoch 600 loss=1.556991 wdloss=0.900534
# epoch 700 loss=1.477242 wdloss=1.019220
# epoch 800 loss=1.369059 wdloss=1.131037
# epoch 900 loss=1.178981 wdloss=1.218395
# epoch 1000 loss=1.096445 wdloss=1.287402
# epoch 1100 loss=0.986739 wdloss=1.335490
# epoch 1200 loss=0.930707 wdloss=1.382353
# epoch 1300 loss=0.886602 wdloss=1.430477
# epoch 1400 loss=0.877665 wdloss=1.453030
# epoch 1500 loss=0.808827 wdloss=1.484334
# epoch 1600 loss=0.763587 wdloss=1.503576
# epoch 1700 loss=0.740971 wdloss=1.534223
# epoch 1800 loss=0.708385 wdloss=1.528679
# epoch 1900 loss=0.698352 wdloss=1.540701
# epoch 2000 loss=0.719777 wdloss=1.573603
# epoch 2100 loss=0.691175 wdloss=1.569903
# epoch 2200 loss=0.680360 wdloss=1.579395
# epoch 2300 loss=0.691409 wdloss=1.594536
# epoch 2400 loss=0.622338 wdloss=1.576014
# epoch 2500 loss=0.644852 wdloss=1.564779
# epoch 2600 loss=0.710932 wdloss=1.579443
# epoch 2700 loss=0.764861 wdloss=1.589101
# epoch 2800 loss=0.785836 wdloss=1.575209
# epoch 2900 loss=0.640416 wdloss=1.582529
# epoch 2999 loss=0.652157 wdloss=1.604628
# Finished training
# Completed split 4
# Finished making poly
# epoch 0 loss=15.426143 wdloss=0.333081
# epoch 100 loss=5.110239 wdloss=0.292884
# epoch 200 loss=2.729796 wdloss=0.391867
# epoch 300 loss=2.263416 wdloss=0.531328
# epoch 400 loss=1.962359 wdloss=0.665849
# epoch 500 loss=1.795718 wdloss=0.808150
# epoch 600 loss=1.578847 wdloss=0.925221
# epoch 700 loss=1.403039 wdloss=1.041093
# epoch 800 loss=1.283668 wdloss=1.139608
# epoch 900 loss=1.167247 wdloss=1.223925
# epoch 1000 loss=1.111678 wdloss=1.295443
# epoch 1100 loss=1.027489 wdloss=1.357358
# epoch 1200 loss=0.960127 wdloss=1.403377
# epoch 1300 loss=0.911653 wdloss=1.439622
# epoch 1400 loss=0.868609 wdloss=1.468311
# epoch 1500 loss=0.816294 wdloss=1.494849
# epoch 1600 loss=0.790646 wdloss=1.515965
# epoch 1700 loss=0.761870 wdloss=1.533339
# epoch 1800 loss=0.728932 wdloss=1.532050
# epoch 1900 loss=0.763788 wdloss=1.548945
# epoch 2000 loss=0.762195 wdloss=1.566713
# epoch 2100 loss=0.735580 wdloss=1.588853
# epoch 2200 loss=0.697172 wdloss=1.598511
# epoch 2300 loss=0.675497 wdloss=1.603776
# epoch 2400 loss=0.653663 wdloss=1.606990
# epoch 2500 loss=0.638298 wdloss=1.596076
# epoch 2600 loss=0.664613 wdloss=1.605540
# epoch 2700 loss=0.741086 wdloss=1.596803
# epoch 2800 loss=0.722768 wdloss=1.606344
# epoch 2900 loss=0.648155 wdloss=1.606910
# epoch 2999 loss=0.735249 wdloss=1.611474
# Finished training
# Completed split 5
# Finished making poly
# epoch 0 loss=16.280233 wdloss=0.332900
# epoch 100 loss=5.030538 wdloss=0.291246
# epoch 200 loss=2.686665 wdloss=0.401828
# epoch 300 loss=2.222669 wdloss=0.546227
# epoch 400 loss=1.929059 wdloss=0.686384
# epoch 500 loss=1.694439 wdloss=0.831908
# epoch 600 loss=1.528019 wdloss=0.959405
# epoch 700 loss=1.388669 wdloss=1.081938
# epoch 800 loss=1.266938 wdloss=1.174364
# epoch 900 loss=1.124520 wdloss=1.252282
# epoch 1000 loss=1.058076 wdloss=1.313651
# epoch 1100 loss=1.002259 wdloss=1.368860
# epoch 1200 loss=0.932872 wdloss=1.414772
# epoch 1300 loss=0.861484 wdloss=1.447499
# epoch 1400 loss=0.854878 wdloss=1.468637
# epoch 1500 loss=0.772476 wdloss=1.496639
# epoch 1600 loss=0.722640 wdloss=1.492116
# epoch 1700 loss=0.740353 wdloss=1.508344
# epoch 1800 loss=0.714313 wdloss=1.519131
# epoch 1900 loss=0.782774 wdloss=1.532316
# epoch 2000 loss=0.698780 wdloss=1.526211
# epoch 2100 loss=0.692903 wdloss=1.557619
# epoch 2200 loss=0.736563 wdloss=1.575881
# epoch 2300 loss=0.648966 wdloss=1.564112
# epoch 2400 loss=0.639818 wdloss=1.569335
# epoch 2500 loss=0.649779 wdloss=1.562204
# epoch 2600 loss=0.724549 wdloss=1.571264
# epoch 2700 loss=0.680546 wdloss=1.579200
# epoch 2800 loss=0.651848 wdloss=1.584474
# epoch 2900 loss=0.665733 wdloss=1.577447
# epoch 2999 loss=0.726702 wdloss=1.609426
# Finished training
# Completed split 6
# Finished making poly
# epoch 0 loss=15.417935 wdloss=0.333355
# epoch 100 loss=5.618059 wdloss=0.281799
# epoch 200 loss=2.714164 wdloss=0.375693
# epoch 300 loss=2.325409 wdloss=0.490895
# epoch 400 loss=2.028041 wdloss=0.625847
# epoch 500 loss=1.787737 wdloss=0.744327
# epoch 600 loss=1.647110 wdloss=0.871673
# epoch 700 loss=1.438575 wdloss=0.974538
# epoch 800 loss=1.337248 wdloss=1.077984
# epoch 900 loss=1.204935 wdloss=1.152595
# epoch 1000 loss=1.096496 wdloss=1.234950
# epoch 1100 loss=1.006521 wdloss=1.286694
# epoch 1200 loss=0.964548 wdloss=1.345827
# epoch 1300 loss=0.906354 wdloss=1.377294
# epoch 1400 loss=0.864316 wdloss=1.414569
# epoch 1500 loss=0.879001 wdloss=1.448848
# epoch 1600 loss=0.780937 wdloss=1.462635
# epoch 1700 loss=0.750460 wdloss=1.472899
# epoch 1800 loss=0.737905 wdloss=1.481751
# epoch 1900 loss=0.692279 wdloss=1.471471
# epoch 2000 loss=0.723406 wdloss=1.484569
# epoch 2100 loss=0.736992 wdloss=1.514238
# epoch 2200 loss=0.691606 wdloss=1.502994
# epoch 2300 loss=0.714439 wdloss=1.514403
# epoch 2400 loss=0.716686 wdloss=1.520455
# epoch 2500 loss=0.646075 wdloss=1.513497
# epoch 2600 loss=0.660096 wdloss=1.525444
# epoch 2700 loss=0.665071 wdloss=1.552131
# epoch 2800 loss=0.656097 wdloss=1.553125
# epoch 2900 loss=0.685850 wdloss=1.545707
# epoch 2999 loss=0.670605 wdloss=1.588476
# Finished training
# Completed split 7
# Finished making poly
# epoch 0 loss=15.904990 wdloss=0.333710
# epoch 100 loss=5.287060 wdloss=0.304660
# epoch 200 loss=2.744266 wdloss=0.391797
# epoch 300 loss=2.356266 wdloss=0.538278
# epoch 400 loss=1.961379 wdloss=0.669940
# epoch 500 loss=1.752941 wdloss=0.815896
# epoch 600 loss=1.604846 wdloss=0.930812
# epoch 700 loss=1.448325 wdloss=1.054746
# epoch 800 loss=1.293716 wdloss=1.159388
# epoch 900 loss=1.187072 wdloss=1.235684
# epoch 1000 loss=1.101451 wdloss=1.300260
# epoch 1100 loss=1.020763 wdloss=1.360615
# epoch 1200 loss=0.983286 wdloss=1.402535
# epoch 1300 loss=0.863198 wdloss=1.442597
# epoch 1400 loss=0.820815 wdloss=1.452131
# epoch 1500 loss=0.822129 wdloss=1.475397
# epoch 1600 loss=0.774214 wdloss=1.500432
# epoch 1700 loss=0.738403 wdloss=1.516337
# epoch 1800 loss=0.728560 wdloss=1.543596
# epoch 1900 loss=0.695442 wdloss=1.543230
# epoch 2000 loss=0.675422 wdloss=1.550021
# epoch 2100 loss=0.694027 wdloss=1.558018
# epoch 2200 loss=0.695431 wdloss=1.562758
# epoch 2300 loss=0.675200 wdloss=1.575812
# epoch 2400 loss=0.713726 wdloss=1.584728
# epoch 2500 loss=0.648894 wdloss=1.574073
# epoch 2600 loss=0.610968 wdloss=1.560849
# epoch 2700 loss=0.631718 wdloss=1.579336
# epoch 2800 loss=0.684000 wdloss=1.595445
# epoch 2900 loss=0.817787 wdloss=1.602903
# epoch 2999 loss=0.664122 wdloss=1.606004
# Finished training
# Completed split 8
# Finished making poly
# epoch 0 loss=16.441675 wdloss=0.333701
# epoch 100 loss=4.888180 wdloss=0.306903
# epoch 200 loss=2.606887 wdloss=0.432808
# epoch 300 loss=2.217918 wdloss=0.577019
# epoch 400 loss=1.880753 wdloss=0.726964
# epoch 500 loss=1.652458 wdloss=0.862762
# epoch 600 loss=1.493551 wdloss=0.994148
# epoch 700 loss=1.286513 wdloss=1.089101
# epoch 800 loss=1.170399 wdloss=1.175851
# epoch 900 loss=1.118644 wdloss=1.241000
# epoch 1000 loss=1.027776 wdloss=1.305039
# epoch 1100 loss=0.974345 wdloss=1.349146
# epoch 1200 loss=0.907205 wdloss=1.397260
# epoch 1300 loss=0.872392 wdloss=1.425986
# epoch 1400 loss=0.823686 wdloss=1.470601
# epoch 1500 loss=0.794804 wdloss=1.485016
# epoch 1600 loss=0.742537 wdloss=1.511374
# epoch 1700 loss=0.715875 wdloss=1.527266
# epoch 1800 loss=0.743442 wdloss=1.551769
# epoch 1900 loss=0.837814 wdloss=1.537729
# epoch 2000 loss=0.707722 wdloss=1.550355
# epoch 2100 loss=0.765046 wdloss=1.555683
# epoch 2200 loss=0.739409 wdloss=1.561508
# epoch 2300 loss=0.683833 wdloss=1.551995
# epoch 2400 loss=0.626764 wdloss=1.539784
# epoch 2500 loss=0.646048 wdloss=1.550998
# epoch 2600 loss=0.633334 wdloss=1.551949
# epoch 2700 loss=0.702606 wdloss=1.561315
# epoch 2800 loss=0.634958 wdloss=1.548581
# epoch 2900 loss=0.639075 wdloss=1.566901
# epoch 2999 loss=0.660806 wdloss=1.574418
# Finished training
# Completed split 9
# Complete

# %%
import matplotlib.pyplot as plt
import math

# y = X_train[:,0]
# idcs = torch.arange(0,len(y))
# yPred = maskgcn([True, idcs]).detach().numpy().flatten()

y = X_all[:,0]
yPred = agesPredMLP
print()    
    
idcs = np.argsort(y)
yPred = yPred[idcs]
y = y[idcs]

corr = np.corrcoef(y, yPred)
rmse = (np.sum((y-yPred)**2)/len(y))**0.5/12
mae = np.sum(np.abs(y-yPred))/12/len(y)

print(corr)
print(rmse)
print(mae)

plt.plot(y, label='Truth')
plt.plot(yPred, label='Prediction')
plt.show()

plt.scatter(y, yPred)
plt.show()
# Out:
# [[1.         0.73711633]
#  [0.73711633 1.        ]]
# 2.198312157870918
# 1.7622670950415162

# %%
# Get standard deviations

rmse = np.zeros(10)
mae = np.zeros(10)
corr = np.zeros(10)

idx = 0
for trainIdcs, testIdcs in groups:
    y = X_all[testIdcs,0]
    yPred = agesPredMLP[testIdcs]
    
    corr[idx] = np.corrcoef(y, yPred)[0,1]
    rmse[idx] = (np.sum((y-yPred)**2)/len(y))**0.5/12
    mae[idx] = np.sum(np.abs(y-yPred))/12/len(y)
   
    idx += 1
    
print(np.mean(rmse))
print(np.std(rmse))
print(np.mean(mae))
print(np.std(mae))
print(np.mean(corr))
print(np.std(corr))
# Out:
# 2.1876096420670126
# 0.2222449571028552
# 1.7630191073265002
# 0.16523119193482214
# 0.7371296580561685
# 0.06456289916553289

# %%
# Save predictions

with open('../../Work/Abstract/PaperBin/MLP-5-Predictions-3-Emoid.bin', 'wb') as f:
    pickle.dump(agesPredMLP, f)
    
print('Complete')
# Out:
# Complete

# %%
# Check predictions

with open('../../Work/Abstract/PaperBin/MLP-5-Predictions-3-Emoid.bin', 'rb') as f:
    check = pickle.load(f)
    
rmse = np.zeros(10)
mae = np.zeros(10)
corr = np.zeros(10)

idx = 0
for trainIdcs, testIdcs in groups:
    y = X_all[testIdcs,0]
    yPred = check[testIdcs]
    
    corr[idx] = np.corrcoef(y, yPred)[0,1]
    rmse[idx] = (np.sum((y-yPred)**2)/len(y))**0.5/12
    mae[idx] = np.sum(np.abs(y-yPred))/12/len(y)
   
    idx += 1
    
print(np.mean(rmse))
print(np.std(rmse))
print(np.mean(mae))
print(np.std(mae))
print(np.mean(corr))
print(np.std(corr))
# Out:
# 2.1876096420670126
# 0.2222449571028552
# 1.7630191073265002
# 0.16523119193482214
# 0.7371296580561685
# 0.06456289916553289

# %%
idx = 4
w1 = mlp.fc1.weight[0,idx*(nRoi*nRoi):(idx+1)*(nRoi*nRoi)].detach().cpu().reshape(nRoi,nRoi)
print(w1.shape)
plt.imshow(w1)
plt.colorbar()
plt.show()
# Out:
# torch.Size([264, 264])

# %%
with open('../../Work/Abstract/PaperBin/MLP-5-Weights-3-Emoid.bin', 'wb') as f:
    pickle.dump(mlp.fc1.weight.detach().cpu().numpy(), f)
    
print('Complete')
# Out:
# Complete

# %%
# Age Prediction Using Power FC, Ridge and Torch
# Scan 2, alpha=1000

import matplotlib.pyplot as plt

trsize = [100, 200, 500, 1000, 3000, 5000, 10000, 15000, 40000]
null = 7.623965856224979
ridge = [7.5242137849600095, 7.307207305408802, 6.560694624621112, 6.460765886743367, 
         6.037899925188521, 5.845812524772894, 5.628426261731364]
latsim = [7.949969050732787, 8.003776606516064, 7.026499196437777, 6.8131216065406885, 
          6.211019703497503, 6.003760187269348, 5.792676918359775, 5.651370470074392]
ridge21 = [8.619584829911906, 7.77166148383432, 7.652378255579106, 7.37046115517529,
           7.023555339887691, 6.844776510473099, 6.705391201237582, 6.7701810478916,
           6.706075250882556]
ridge55 = [7.784151359915962, 7.653986236483196, 7.793943423910511, 8.027059622617207,
           7.265664598707488, 6.663147116454543, 6.178696394534465, 5.931109423355452,
           5.73747989008111]
ridge21pc = [7.770714221132357, 7.380744656195485, 6.985023085590809, 7.106347203305551,
             6.874495024237487, 6.75499873602311, 6.676084571277282, 6.653875770018566,
             6.561049097268271]
ridge55pc = [7.5730375120600915, 7.132151588889395, 6.468228717861055, 6.358500409947508,
             6.018410755806411, 5.889044218771669, 5.669351166769304, 5.629254827981727,
             5.517217050310029]
ridge21comp = [8.286495007054176, 7.813612946958807, 7.623787330495074, 7.44690789329658,
               7.397171952577219, 7.341879158410482, 7.283817983888544, 7.259034338099471,
               7.240053121871716]
ridge55comp = [7.59167948442186, 7.421483364010308, 7.2324717206527955, 7.160526679187714,
               7.051024801132517, 6.960193439350399, 6.9585613186242234, 6.9096718721403105,
               6.877270434639575]

fig, ax = plt.subplots(1,3,figsize=[18,4])

ax[0].plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax[0].plot(trsize[:7], ridge[:7], label='Ridge Power264')
ax[0].plot(trsize, ridge21, label='Ridge ICA21')
ax[0].plot(trsize, ridge55, label='Ridge ICA55')
ax[0].plot(trsize[:8], latsim[:8], label='LatSim Power264')
ax[0].set_title('Age Prediction using FC')
ax[0].set_ylabel('RMSE (years)')
ax[0].set_xlabel('# Training Subjects')
ax[0].legend()
ax[0].text(20000,7.0,'Ridge: $\\alpha$=1000')
ax[0].set_ylim([5.4,8.7])

ax[1].plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax[1].plot(trsize, ridge21pc, label='Ridge ICA21')
ax[1].plot(trsize, ridge55pc, label='Ridge ICA55')
ax[1].set_title('Age Prediction using PC')
ax[1].set_ylabel('RMSE (years)')
ax[1].set_xlabel('# Training Subjects')
ax[1].legend()
ax[1].text(20000,7.0,'Ridge: $\\alpha$=1000')
ax[1].set_ylim([5.4,8.7])

ax[2].plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax[2].plot(trsize, ridge21comp, label='Ridge ICA21')
ax[2].plot(trsize, ridge55comp, label='Ridge ICA55')
ax[2].set_title('Age Prediction using Component Amplitudes')
ax[2].set_ylabel('RMSE (years)')
ax[2].set_xlabel('# Training Subjects')
ax[2].legend()
ax[2].text(20000,6.0,'Ridge: $\\alpha$=10')
ax[2].set_ylim([5.4,8.7])

fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/UKB/ukb_age_pred.pdf')
# Out:
# /tmp/ipykernel_59223/3981563166.py:65: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Sex Prediction Power FC, Logistic and LatSim
# Scan 2, max_iter=1000

import matplotlib.pyplot as plt

trsize = [100, 200, 500, 1000, 3000, 5000, 10000, 15000, 40000]
trsize_latsim55 = [100, 200, 500, 1000, 3000, 5000, 10000, 15000, 20000, 30000]
null = 0.528
logistic = [0.6325000000000001, 0.74375, 0.776, 0.8059999999999998]
latsim = [0.635, 0.75, 0.7605, 0.7915,
          0.8264166666666666, 0.8487500000000001, 0.8632000000000002, 0.86425]
logistic21 = [0.67, 0.6137499999999999, 0.701, 0.71925, 
              0.7671666666666668, 0.7820500000000001, 0.7822, 0.7881,
              0.7919820275914442]
logistic55 = [0.7024999999999999, 0.7099999999999999, 0.7845, 0.8092500000000001,
              0.8447500000000001, 0.85985, 0.8499500000000001]
latsim55 = [0.5875, 0.58375, 0.6535, 0.715,
            0.7851666666666667, 0.796, 0.8252499999999999, 0.8438000000000001,
            0.8526000000000001, 0.8612083333333332]
logistic21pc = [0.605, 0.635, 0.6960000000000001, 0.72425,
                0.7935833333333333, 0.8002500000000001, 0.7970999999999999, 0.8098833333333332,
                0.8046006834577902]
logistic55pc = [0.7525000000000001, 0.835, 0.8584999999999999, 0.869,
                0.8793333333333335, 0.8863999999999999, 0.8859999999999999]
latsim55pc = [0.6675, 0.74, 0.821, 0.8484999999999999,
              0.8864166666666666, 0.88825, 0.89865, 0.9085666666666665,
              0.9119624999999999, 0.9181166666666666]
logistic21comp = [0.6925, 0.6993750000000001, 0.6897500000000001, 0.6799375,
                  0.6729, 0.6712833333333332, 0.6691357142857142, 0.668875,
                  0.668739099859353]
logistic55comp = [0.5800000000000001, 0.618125, 0.6622500000000001, 0.6829375,
                  0.7000166666666666, 0.7137472222222222, 0.7194976190476191, 0.7272854166666667,
                  0.7338008204406938]

fig, ax = plt.subplots(1,3,figsize=(18,4))

ax[0].plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax[0].plot(trsize, logistic21, label='Logistic ICA21')
ax[0].plot(trsize[:7], logistic55[:7], label='Logistic ICA55')
ax[0].plot(trsize[:4], logistic[:4], label='Logistic Power264')
ax[0].plot(trsize[:8], latsim[:8], label='LatSim Power264')
ax[0].plot(trsize_latsim55, latsim55, label='LatSim ICA55')
ax[0].set_title('Sex Prediction using FC')
ax[0].set_xlabel('# Training Subjects')
ax[0].set_ylabel('Accuracy')
ax[0].set_ylim([0.45,0.93])
ax[0].legend()

ax[1].plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax[1].plot(trsize, logistic21pc, label='Logistic ICA21')
ax[1].plot(trsize[:7], logistic55pc[:7], label='Logistic ICA55')
ax[1].plot(trsize_latsim55, latsim55pc, label='LatSim ICA55')
ax[1].set_title('Sex Prediction using PC')
ax[1].set_xlabel('# Training Subjects')
ax[1].set_ylabel('Accuracy')
ax[1].set_ylim([0.45,0.93])
ax[1].legend()

ax[2].plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax[2].plot(trsize, logistic21comp, label='Logistic ICA21')
ax[2].plot(trsize, logistic55comp, label='Logistic ICA55')
ax[2].set_title('Sex Prediction using Component Amplitudes')
ax[2].set_xlabel('# Training Subjects')
ax[2].set_ylabel('Accuracy')
ax[2].set_ylim([0.45,0.93])
ax[2].legend()

fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/UKB/ukb_sex_pred.pdf')
# Out:
# /tmp/ipykernel_59223/520914784.py:68: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Sex prediction MLP

import matplotlib.pyplot as plt

trsize = [100, 200, 500, 1000, 3000, 5000, 10000, 15000, 40000]
null = 0.528
ica21fc = [0.6670041, 0.6787116, 0.71807367, 0.74601316, 
           0.77116823, 0.7756297, 0.79005826, 0.79531074,
           0.7984749]
ica55fc = [0.722282, 0.75424, 0.80470824, 0.8364131,
           0.8675484, 0.8821985, 0.8939059, 0.9034616,
           0.90868247]
ica21pc = [0.6739336, 0.7014935, 0.7384192, 0.76224524,
           0.7910708, 0.7931907, 0.8008797, 0.8113846,
           0.8155613]
ica55pc = [0.7654431, 0.81075954, 0.848481, 0.8746203,
           0.88563293, 0.895095, 0.91351265, 0.920443,
           0.9256962]
power264fc = [0.67512506, 0.707, 0.75512505, 0.80100006,
            0.8457501, 0.87737507, 0.89775, 0.89383334]
power264pc = [0.6253333, 0.66475, 0.75475, 0.79941666,
              0.85074997, 0.87333333, 0.9, 0.90599996]

fig, ax = plt.subplots(1,1,figsize=(6,4))

ax.plot([0,trsize[-1]],[null,null],linestyle='--',color='black',label='Null Model')
ax.plot(trsize, ica21fc, label='ICA21 FC')
ax.plot(trsize, ica55fc, label='ICA55 FC')
ax.plot(trsize, ica21pc, label='ICA21 PC')
ax.plot(trsize, ica55pc, label='ICA55 PC')
ax.plot(trsize[:8], power264fc[:8], label='Power264 FC')
ax.plot(trsize[:8], power264pc[:8], label='Power264 PC')
ax.set_title('Sex Prediction with MLP (Deep Learning)')
ax.set_xlabel('# Training Subjects')
ax.set_ylabel('Accuracy')
ax.set_ylim([0.45,0.94])
ax.legend()

fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/UKB/ukb_sex_mlp_pred.pdf')
# Out:
# /tmp/ipykernel_300069/2459193069.py:39: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Race prediction results on matched cohorts

import matplotlib.pyplot as plt

race = ['111 African', '148 Caribbean', '282 Indian', '111 Chinese', '61 Pakistani', '300 Sex']
ica100fc = [0.8644444444444443, 0.8133333333333332, 0.7150442477876107, 0.7666666666666666,
            0.6799999999999999, 0.8258333333333333]
ica100fc_err = [0.04812535072823936, 0.042031734043061646, 0.03445649970607396, 0.043603148600774654,
                0.07155417527999326, 0.03504956807468848]

fig, ax = plt.subplots(1,1,figsize=(10,4))

ax.set_title('Race prediction ICA55 FC, Logistic Regression\nBalanced Training Set')
ax.bar(race, ica100fc, yerr=ica100fc_err, capsize=5)
ax.set_ylim([0.45,0.95])
ax.plot([-0.3,5.3],[0.5,0.5],linestyle='--',color='black',label='Null Model')
ax.legend()
fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/UKB/race_pred.pdf')

# %%
# Longitudinal Logistic simple difference

import matplotlib.pyplot as plt

samples = [20, 30, 50, 100, 200, 400, 800, 1300, 2000]
power264fc = [0.5700000000000001, 0.6, 0.69, 0.694,
              0.7294999999999999, 0.7532500000000001, 0.7987499999999998, 0.8177777777777777,
              0.8314814814814815]
ica55fc = [0.5850000000000001, 0.66, 0.666, 0.674,
           0.71, 0.7180000000000001, 0.7494999999999999, 0.7575384615384616, 
           0.7542307692307693]
ica55pc = [0.6500000000000001, 0.6633333333333333, 0.702, 0.7460000000000001,
           0.7675000000000001, 0.78125, 0.7919999999999999, 0.7975384615384615,
           0.8048076923076923]

fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.set_title('Which scan of same subject is younger?\nLogistic Regression on A-B')
ax.plot(samples, power264fc, label='Power264 FC', marker='o')
ax.plot(samples, ica55fc, label='ICA55 FC', marker='v')
ax.plot(samples, ica55pc, label='ICA55 PC', marker='^')
ax.set_ylim([0.45,0.9])
ax.plot([-0.3,2000],[0.5,0.5],linestyle='--',color='black',label='Null Model')
ax.set_xlabel('# Training Subjects')
ax.set_ylabel('Accuracy')
ax.legend()
fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/UKB/long_older_pred2.pdf')

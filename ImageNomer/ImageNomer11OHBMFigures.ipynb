# %%
import matplotlib.pyplot as plt
import numpy as np

# Emoid
lstsq_lstsqw = [35.95902843,34.77869034,33.50191755,34.64778032,39.56946507,830.739801,43.10355988]
mlp_lstsqw = [38.2118618,37.94225864,36.44578094,35.45468979,34.72987976,31.62912931,30.0897543]
latsim_lstsqw = [37.98100643,37.76096611,34.87876396,32.04681559,29.75678968,26.75905876,25.91120558]

lstsq_lstsqw = np.array(lstsq_lstsqw)
mlp_lstsqw = np.array(mlp_lstsqw)
latsim_lstsqw = np.array(latsim_lstsqw)

lstsq_lstsqdev = [1.532489907,1.563064192,1.978521486,1.584856962,2.739800911,773.1535437,2.82238455]
mlp_lstsqdev = [1.61024913,1.485779027,1.340721368,1.494849796,1.24052241,1.507825966,1.141939407]
latsim_lstsqdev = [1.712807556,1.703547289,1.640052913,1.473167628,1.674656266,1.168785885,1.145628098]

lstsq_lstsqdev = np.array(lstsq_lstsqdev)

lstsq_base = 27.2
mlp_base = 29.9
latsim_base = 27.7
null = 39

x = [2,10,30,50,100,200,300]

fig, ax = plt.subplots(1,1)
ax.plot([-50,350],[null,null], linestyle='--', color='black', linewidth='1')
ax.plot([-50,350],[lstsq_base,lstsq_base], linestyle='--', color='black', linewidth='1')
ax.plot([-50,350],[mlp_base,mlp_base], linestyle='--', color='black', linewidth='1')
ax.plot([-50,350],[latsim_base,latsim_base], linestyle='--', color='black', linewidth='1')
ax.plot(x,lstsq_lstsqw, label='Least Squares')
ax.fill_between(x, lstsq_lstsqw-lstsq_lstsqdev, lstsq_lstsqw+lstsq_lstsqdev, alpha=0.3)
ax.plot(x,mlp_lstsqw, label='MLP')
ax.fill_between(x, mlp_lstsqw-mlp_lstsqdev, mlp_lstsqw+mlp_lstsqdev, alpha=0.3)
ax.plot(x,latsim_lstsqw, label='LatSim')
ax.fill_between(x, latsim_lstsqw-latsim_lstsqdev, latsim_lstsqw+latsim_lstsqdev, alpha=0.3)
ax.legend()
ax.set_ylim(20,45)
ax.set_xlim(0,300)
# ax.annotate('"Double descent"', xy=(300, 43.1), xytext=(150, 43.5),
#             arrowprops=dict(arrowstyle="->"))
ax.text(150,39.5,"Null model")
ax.text(10,30.3,"Base MLP")
ax.text(10,28.2,"Base LatSim")
ax.text(10,26,"Base Least Squares")
ax.set_xlabel('# of Selected Features')
ax.set_ylabel('Age Prediction RMSE (months)')
ax.set_title("Connectivity Selection using Least Squares Weights (FC):\nEmotion ID Task")
fig.show()
fig.savefig('../../Work/ImageNomer/FiguresOHBM/emoid-fc-selection.pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Emoid
lstsq_lstsqw = [32.67810345,33.21734629,33.07665653,34.38488331,41.05887127,765.2590607,52.30753803]
mlp_lstsqw = [38.6411974,38.30937939,38.32559834,37.0815115,35.84027042,34.65781765,33.22924156]
latsim_lstsqw = [38.57593765,38.29561768,38.22590389,37.89062138,35.9114603,32.46085968,31.53140125]

lstsq_lstsqw = np.array(lstsq_lstsqw)
mlp_lstsqw = np.array(mlp_lstsqw)
latsim_lstsqw = np.array(latsim_lstsqw)

lstsq_lstsqdev = [1.326909913,1.701858399,1.686142851,1.577373121,2.523677289,630.54872,2.916709859]
mlp_lstsqdev = [1.071009126,1.96557848,1.70150767,1.636175185,1.333227313,1.114053031,1.000429629]
latsim_lstsqdev = [1.057442353,1.962204935,1.716449929,2.102109974,3.151774199,1.633736248,1.456226828]

lstsq_lstsqdev = np.array(lstsq_lstsqdev)

lstsq_base = 30.2
mlp_base = 32.5
latsim_base = 31.4
null = 39

x = [2,10,30,50,100,200,300]

fig, ax = plt.subplots(1,1)
ax.plot([-50,350],[null,null], linestyle='--', color='black', linewidth='1')
ax.plot([-50,350],[lstsq_base,lstsq_base], linestyle='--', color='black', linewidth='1')
ax.plot([-50,350],[mlp_base,mlp_base], linestyle='--', color='black', linewidth='1')
ax.plot([-50,350],[latsim_base,latsim_base], linestyle='--', color='black', linewidth='1')
ax.plot(x,lstsq_lstsqw, label='Least Squares')
ax.fill_between(x, lstsq_lstsqw-lstsq_lstsqdev, lstsq_lstsqw+lstsq_lstsqdev, alpha=0.3)
ax.plot(x,mlp_lstsqw, label='MLP')
ax.fill_between(x, mlp_lstsqw-mlp_lstsqdev, mlp_lstsqw+mlp_lstsqdev, alpha=0.3)
ax.plot(x,latsim_lstsqw, label='LatSim')
ax.fill_between(x, latsim_lstsqw-latsim_lstsqdev, latsim_lstsqw+latsim_lstsqdev, alpha=0.3)
ax.legend()
ax.set_ylim(20,45)
ax.set_xlim(0,300)
# ax.annotate('"Double descent"', xy=(300, 43.1), xytext=(150, 43.5),
#             arrowprops=dict(arrowstyle="->"))
ax.text(140,39.5,"Null model")
ax.text(10,29,"Base MLP")
ax.text(10,28,"Base LatSim")
ax.text(10,27,"Base Least Squares")
ax.set_xlabel('# of Selected Features')
ax.set_ylabel('Age Prediction RMSE (months)')
ax.set_title("Important Connectivity Selection using Product of\nPC and Least Squares Weights (PC):\nnback Task")
fig.show()
fig.savefig('../../Work/ImageNomer/FiguresOHBM/nback-pc-selection.pdf')

# %%
import matplotlib.pyplot as plt
import nilearn.plotting as niplt
import matplotlib.patches as mpatches
import numpy as np

fig, ax = plt.subplots(1,1)

# Remapped to original ROIs
# Numbers are 1 less than in XLS file (0-indexing)

A = np.zeros((4,4))
A[0,1] = 1
A[2,3] = 1
A = A+A.T

# Lentiform nucleus in Putamen
r204 = (-22,7,-5)
r207 = (23,10,1)
# Right Cerebellum Uvula (DMN) to Right Cerebellum (Uvula, CB)
r113 = (28,-77,-32)
r256 = (17,-80,-34)

niplt.plot_connectome(A,[r204,r207,r113,r256],2*['blue']+2*['orange'],axes=ax,colorbar=False)
ax.set_title("Significant Connections for PC nback Task Age Prediction\n"
             "Explain 20% of Variation in Age\n"
             "Explain 75% of Accuracy of Full 34,716 Connection Model")

fig.show()
fig.savefig('../../Work/ImageNomer/FiguresOHBM/nback-nilearn.pdf')
